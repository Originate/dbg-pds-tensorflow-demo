# %% [markdown]
# # Supporting Notebook 2: (Predictable and unpredicable prices)
#
# ## Modeling: What to Predict
# It is not straightforward to choose how to model stock behavior.
#
# Do we predict prices at 1 minute ahead, 10 minutes, or daily.
#
# Or should we predict all?
#
# What kind of price do we want to predict within an interval:
#
# - EndPrice
# - Mean(EndPrice)
# - WeightedMean(EndPrice)
# - MedianPrice
# - or the complete distribution of prices
# - if the complete distribution is to be predicted, do we predict the mean, variance and the skew. Do we discretize the distribution or we treat the available prices as samples from the distribution that we predict
#
# Another decision is whether to predict:
# - Percent of Change of Price
# - The sign of the price movement
# - The log of the actual price
#
# From a practical perspective, even in the presence of perfect predictions of prices in the future, one may not be able to make any money. This depends on
# - fees (the fee to enter and exit a position) should be lower than the expected change in the price
# - on seeing a quoted price how much above (when buying) and how far below (when selling) will one execute
# - volumes in the market. If one trades with very large volumes one will disrupt the supply and demand mechanism, therefore one will not execute at the desired price.
# - how the broker executes trades matters

# %% [markdown]
# # Insights: what is predictable
#
# In the current notebook we try to get an understanding what is easier and what is difficult to predict.
# For example, we find out that when we organize the data into intervals of say 10, 15, or 30 minutes,
# the mean price (`Mean(EndPrice)`) is much easier to predict than the end price `EndPrice`.
#
# We also find that when normalizing for `PctChange:X` of a feature `X`, we should use features that are normalized in the same way. One way to normalize the features is to divide them by `X[t - 1]`.
#
# One way to avoid this difficulty would be the following:
# - generate different linear combination of prices (averages are also linear combinations, and so are absolute returns)
# - compute the logs of all types of prices (or averages) of prices
# - we may also attempt to predict linear combination of prices, by taking logs
# - notice that is essentially a non-linear model, because we apply logs on sums of raw input features
# - when using logs care must be taken to avoid numbers close to zero as well as negative numbers.
# - however, log returns are approximately equal to percent change, so logs can be avoided
#
# We explore different ways to normalize the prices. One way would be to choose a more stable price as an "anchor", and replace all prices as linear functions such as:
# ```
# AnchorPrice = mean(Price[t - k, t - 1])
# NormPrice:X[i] = (Price:X[i] - AnchorPrice)/AnchorPrice, for i = t, t - 1, ...
# ```
#
#
# Regarding the prediction of an `EndPrice` we hypothesis that one would do better by predicting:
# - predict two prices, one 10 minutes ahead, one 5 minutes ahead
# - find the differences between the predictions
#
#
# In the future we will also explore the possiblity to predict entire distribution of prices, instead of just a single end-price, or averaged prices.

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (5, 3) # use bigger graphs

# %% [markdown]
# As usual we first load the data we prepared in notebook 2

# %%
input_file = '/data/processed/cooked_v3.pkl'
df = pd.read_pickle(input_file)
df['CalcDateTime'] = df.index

# %% [markdown]
# Next we prepare a dataset consting of a single stock and compute derivative features
# (percent change) of a number of price features.

# %%
price_features = ['MaxPrice', 'MinPrice', 'LastEndPrice', 'FirstStartPrice', 'MeanEndPrice', 'MedianEndPrice', 
                  'MeanStartEndPrice', 'MeanMaxMinPrice', 'MeanAvg4Price',
                  'Direction1', 'Direction2', 'StdEndPrice', 'VolumeWeightedEndPrice']

log_ret_features = ['MaxPrice', 'MinPrice', 'LastEndPrice', 'FirstStartPrice', 'MeanEndPrice', 'MedianEndPrice', 
                  'MeanStartEndPrice', 'MeanMaxMinPrice', 'MeanAvg4Price']

indicator_features = [
    'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8',
    'G1', 'G2', 'G3', 'G4'
]

def pct_change_of(feature):
        return 'PctChange:' + feature
    
def log_return_f(feature):
    return 'LogReturn:' + feature

def adj_log_return_f(feature):
    return 'AdjLogReturn:' + feature

def rev_pct_change_of_at_t(feature, t):
        return 'RevPctChange[t - {}]:{}'.format(str(t), feature)
    
def shifted(feature):
    return feature + '[t - 1]'

def closer_to(pnt, a, b):
    return (np.absolute(pnt - a) - np.absolute(pnt - b))/pnt

def closer_to_with_normalization(pnt, a, b, norm):
    return (np.absolute(pnt - a) - np.absolute(pnt - b))/norm

def closer_to_or(pnt1, a, pnt2, b):
    return 2.0*(np.absolute(pnt1 - a) - np.absolute(pnt2 - b))/(pnt1 + pnt2)

def rev_pct_change(a, t):
    one_step_in_past = a.shift(1)
    t_steps_in_past = a.shift(1 + t)
    return (one_step_in_past - t_steps_in_past)/one_step_in_past
    
def log_return(a):
    return np.log(a) - np.log(a.shift(1))

def adj_log_return(a, norm):
    return np.log(a) - np.log(norm)

def norm_feature(feature_family, t, norm_feature):
    return "{}@WithNorm({})[t - {}]".format(feature_family, norm_feature, t)    
    
def weighted_mean(prices, volumes, interval):
    prices_times_volumes = prices * volumes
    num = prices_times_volumes.resample(interval).sum()
    denom = volumes.resample(interval).sum()
    return num/denom
    
# use this to experiment with custom weights    
def custom_linear_comb(prices):
    prices = prices.values[:,]
    prices = prices[~np.isnan(prices)]
    if prices.shape[0] == 0:
        return np.nan
    weights = np.zeros_like(prices)
    if prices.shape[0] < 3:
        return prices[-1]
    weights[-1] = 1.0
    weights[-2] = 0.5
    return np.sum(np.multiply(prices, weights))/np.sum(weights)    

def prepare_single_stock(mnemonic, interval):
    # TODO: add traded volume to averaging of prices, also traded volume weighted differently (e.g. exponential weighting)
    # TODO: one can weight max/min/start/end price differently depending on the move
    # TODO: add exponential weighting of the prices within a window (also there are different ways to center)
    single_stock = df[df.Mnemonic == mnemonic].copy()
    single_stock['StartEndPrice'] = 0.5*(single_stock['StartPrice'] + single_stock['EndPrice'])
    single_stock['MaxMinPrice'] = 0.5*(single_stock['MaxPrice'] + single_stock['MinPrice'])
    single_stock['Avg4Price'] = 0.25*(single_stock['MaxPrice'] + single_stock['MinPrice'] + 
                                      single_stock['StartPrice'] + single_stock['EndPrice'])
    
    # TODO: add smoothed traded volume
    single_stock['PctChange'] = single_stock['EndPrice'].pct_change()
    single_stock['SmoothedTradedVolume'] = single_stock['TradedVolume'].ewm(com=2.5).mean()
    
    single_stock['Direction'] = \
        2.0*(single_stock['EndPrice'] - single_stock['StartPrice'])/ \
        (single_stock['EndPrice'] + single_stock['StartPrice'])
        
    single_stock['F1'] = - closer_to(single_stock['EndPrice'], single_stock['MaxPrice'], single_stock['MinPrice'])
        

    resampled = pd.DataFrame({
        'MaxPrice': single_stock['MaxPrice'].resample(interval).max(),
        'MinPrice': single_stock['MinPrice'].resample(interval).min(),
        'MeanStartEndPrice': single_stock['StartEndPrice'].resample(interval).mean(),  
        'MeanMaxMinPrice': single_stock['MaxMinPrice'].resample(interval).mean(), 
        'MeanAvg4Price': single_stock['Avg4Price'].resample(interval).mean(),  
        'CustomLinearComb': single_stock['Avg4Price'].resample(interval).apply(custom_linear_comb),         
        'FirstStartPrice': single_stock['StartPrice'].resample(interval).first(),        
        'LastEndPrice': single_stock['EndPrice'].resample(interval).last(), 
        'MeanEndPrice': single_stock['EndPrice'].resample(interval).mean(), 
        'MedianEndPrice': single_stock['EndPrice'].resample(interval).median(),
        'VolumeWeightedEndPrice': weighted_mean(single_stock['EndPrice'], single_stock['SmoothedTradedVolume'], interval),
        'VolumeWeightedPctChange': weighted_mean(single_stock['PctChange'], single_stock['SmoothedTradedVolume'], interval),
        
        'StdEndPrice': single_stock['EndPrice'].resample(interval).std(),
        'HasTrade': single_stock['HasTrade'].resample(interval).max(),
        'G1': single_stock['Direction'].resample(interval).mean(),
        'G2': np.sign(single_stock['Direction']).resample(interval).mean(),
        'G3': single_stock['F1'].resample(interval).mean(),
        'G4': np.sign(single_stock['F1']).resample(interval).mean()
    })
    resampled['AdjustedPctChange'] = (resampled['LastEndPrice'] - resampled['MeanEndPrice'])/resampled['MeanEndPrice']
    resampled['AdjustedPctChange[t - 1]'] = resampled['AdjustedPctChange'].shift(1)
    
    resampled['MeanPctChangeV2'] = (resampled['MeanEndPrice'] - resampled['LastEndPrice'].shift(1))/resampled['LastEndPrice'].shift(1)
    
    anchor = resampled['MeanEndPrice'].shift(1)
    resampled[adj_log_return_f('LastEndPrice')] = adj_log_return(resampled['LastEndPrice'], anchor)
    resampled[shifted(adj_log_return_f('LastEndPrice'))] = \
        adj_log_return(resampled['LastEndPrice'].shift(1), anchor)
    
    resampled['Direction1'] = \
        2.0*(resampled['LastEndPrice'] - resampled['FirstStartPrice'])/ \
        (resampled['LastEndPrice'] + resampled['FirstStartPrice'])
    
    resampled['Direction2'] = \
        2.0*(resampled['LastEndPrice'] - resampled['FirstStartPrice'])/ \
        resampled['MeanEndPrice'].shift(1)
        
    resampled[shifted('Direction1')] = resampled['Direction1'].shift(1)
    resampled[shifted('Direction2')] = resampled['Direction2'].shift(1)
    
    for f in ['MinPrice', 'MaxPrice', 'LastEndPrice', 'FirstStartPrice']:
        resampled[shifted(f)] = resampled[f].shift(1)
        
    resampled['F1'] = - closer_to(resampled['LastEndPrice'], resampled['MaxPrice'], resampled['MinPrice'])
    resampled['F2'] = - closer_to(resampled['MaxPrice'], resampled['LastEndPrice'], resampled['FirstStartPrice'])
    resampled['F3'] = closer_to(resampled['MinPrice'], resampled['LastEndPrice'], resampled['FirstStartPrice'])
    resampled['F4'] = - closer_to(resampled['LastEndPrice'], resampled['MaxPrice'], resampled[shifted('MaxPrice')])
    resampled['F5'] = closer_to(resampled['LastEndPrice'], resampled['MinPrice'], resampled[shifted('MinPrice')])
    
    resampled['F6'] = - closer_to_or(resampled['LastEndPrice'], resampled['MaxPrice'],
                                   resampled[shifted('LastEndPrice')], resampled[shifted('MaxPrice')])

    resampled['F7'] = closer_to_or(resampled['LastEndPrice'], resampled['MinPrice'],
                                   resampled[shifted('LastEndPrice')], resampled[shifted('MinPrice')])
    
    
    resampled['F8'] = np.where(resampled['Direction2'] >= 0, resampled['F4'] , resampled['F5'])
    
    
    for t in range(1, 5):    
        # note: normalization is fixed
        resampled[norm_feature('H1', t, 'MeanEndPrice')] = - closer_to_with_normalization(
                                             resampled['LastEndPrice'].shift(t), 
                                             resampled['MaxPrice'].shift(t), 
                                             resampled['MinPrice'].shift(t),
                                             resampled['MeanEndPrice'].shift(1))    
        
    
    for f in indicator_features:
        resampled[shifted(f)] = resampled[f].shift(1)
        
    for f in price_features:
        pct_change_f = pct_change_of(f)
        resampled[pct_change_f] = resampled[f].pct_change()
        resampled[shifted(pct_change_f)] = resampled[pct_change_f].shift(1) 
    
    for f in price_features:
        for t in range(1, 5):
            rev_pct_change_f_t = rev_pct_change_of_at_t(f, t)
            resampled[rev_pct_change_f_t] = rev_pct_change(resampled[f], t)    
        

    for f in log_ret_features:
        log_ret_f = log_return_f(f)
        resampled[log_ret_f] = log_return(resampled[f])
        resampled[shifted(log_ret_f)] = resampled[log_ret_f].shift(1) 
        
    resampled = resampled[resampled['HasTrade'] == 1.0]
    
    return resampled

def correlation_with_feature(single_stock, corr_feature):
    pct_change_of_f = corr_feature
    sh_dir1 = shifted('Direction1')
    sh_dir2 = shifted('Direction2')    
    d = {
        pct_change_of_f: single_stock[pct_change_of_f],
        sh_dir1: single_stock[sh_dir1],
        sh_dir2: single_stock[sh_dir2]        
    }
    
    for f in indicator_features:
        d[shifted(f)] = single_stock[shifted(f)]
        
    d['AdjustedPctChange[t - 1]'] = single_stock['AdjustedPctChange[t - 1]']    
    d[adj_log_return_f('LastEndPrice')] = single_stock[adj_log_return_f('LastEndPrice')]
    d[shifted(adj_log_return_f('LastEndPrice'))] = single_stock[shifted(adj_log_return_f('LastEndPrice'))]
    
    d['MeanPctChangeV2'] = single_stock['MeanPctChangeV2']
    
    for f in price_features:
        pct_change_shifted = shifted(pct_change_of(f))
        d[pct_change_shifted] = single_stock[pct_change_shifted]
        
    for t in range(1, 5):    
        # note: normalization is fixed
        f = norm_feature('H1', t, 'MeanEndPrice')
        d[f] = single_stock[f]
            
    for f in log_ret_features:
        log_ret_f = log_return_f(f)
        d[log_ret_f] = single_stock[log_ret_f]
            
    for f in price_features:
        for t in range(1, 5):
            rev_pct_change_f_t = rev_pct_change_of_at_t(f, t)
            d[rev_pct_change_f_t] = single_stock[rev_pct_change_f_t]
            
    d[shifted('VolumeWeightedPctChange')] = single_stock[('VolumeWeightedPctChange')].shift(1)
    corr = pd.DataFrame(d).corr()
    row_id = np.argwhere(corr.index.values == pct_change_of_f)[0][0]
    return corr.iloc[[row_id]].drop(columns=[pct_change_of_f])

def corr_pct_change(single_stock, feature):
    pct_change_of_f = pct_change_of(feature)
    return correlation_with_feature(single_stock, pct_change_of_f)

def corr_log_return(single_stock, feature):
    return correlation_with_feature(single_stock, log_return_f(feature))

def find_most_correlated_features(single_stock, feature):
    corrs = correlation_with_feature(single_stock, feature).T
    corrs['AbsCorr'] = np.absolute(corrs[feature])
    sorted_corrs = corrs.sort_values('AbsCorr', ascending=False)
    selected_names = filter(lambda n: n.find('[t - 1') >= 0 or n.find('[t - 2') >= 0, list(sorted_corrs.index.values))
    sorted_corrs = sorted_corrs.T[selected_names].T
    return sorted_corrs

# %% [markdown]
# We choose a single stock, for example 'SIE' (Siemens)

# %%
single_stock = prepare_single_stock('SIE', '30Min')

# %% [markdown]
# We look at the corrlations of all the other price features from previous time periods `(t - 1)`.
# We could also say that we investigate if a single feature from the previous time period `(t - 1)`
# would be predictive of the change in the next time period `(t)`

# %% [markdown]
# We first study the `LastEndPrice` or the last end price in the interval `t` (here interval is 30 minutes).
# As it can be seen there are no strong correlations.

# %%
corr_pct_change(single_stock, 'LastEndPrice')
# Out:
#                         Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# PctChange:LastEndPrice          -0.014452          -0.031263  -0.028687
#
#                         F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  \
# PctChange:LastEndPrice  -0.014556  -0.014273   0.019518  -0.018305  -0.020372
#
#                         F7[t - 1]  F8[t - 1]  ...  \
# PctChange:LastEndPrice  -0.030215  -0.013344  ...
#
#                         RevPctChange[t - 4]:Direction2  \
# PctChange:LastEndPrice                       -0.025498
#
#                         RevPctChange[t - 1]:StdEndPrice  \
# PctChange:LastEndPrice                         0.004233
#
#                         RevPctChange[t - 2]:StdEndPrice  \
# PctChange:LastEndPrice                        -0.036114
#
#                         RevPctChange[t - 3]:StdEndPrice  \
# PctChange:LastEndPrice                         0.031601
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# PctChange:LastEndPrice                        -0.015092
#
#                         RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:LastEndPrice                                    0.011779
#
#                         RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:LastEndPrice                                    -0.00563
#
#                         RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:LastEndPrice                                   -0.032617
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:LastEndPrice                                   -0.018977
#
#                         VolumeWeightedPctChange[t - 1]
# PctChange:LastEndPrice                       -0.004466
#
# [1 rows x 97 columns]

# %% [markdown]
# Next we look for correlations with the mean prices:
# - MeanAvg4Price: we averaged all 4 prices available within a minute and then averaged within an interval like 10Min
# - MeanMaxMinPrice: took the average of Min and Max prices and then averaged within an interval
# - MeanStartEndPrice: took the average of Start and End prices and then averaged within an interval
#
# # Conclusion:
#
# - The more averaging was done, the easier to predict
# - EndPrice is very difficult to predict, but the mean price is not
# - The median of the end price is harder to predict than the mean, but a lot easier than the end price

# %%
corr_pct_change(single_stock, 'MeanAvg4Price')
# Out:
#                          Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# PctChange:MeanAvg4Price           0.499097           0.545182   0.594027
#
#                          F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  \
# PctChange:MeanAvg4Price   0.500112   0.497522   0.100365   0.098164
#
#                          F6[t - 1]  F7[t - 1]  F8[t - 1]  ...  \
# PctChange:MeanAvg4Price     0.3572   0.337546   0.396958  ...
#
#                          RevPctChange[t - 4]:Direction2  \
# PctChange:MeanAvg4Price                        0.007962
#
#                          RevPctChange[t - 1]:StdEndPrice  \
# PctChange:MeanAvg4Price                         0.000075
#
#                          RevPctChange[t - 2]:StdEndPrice  \
# PctChange:MeanAvg4Price                        -0.036812
#
#                          RevPctChange[t - 3]:StdEndPrice  \
# PctChange:MeanAvg4Price                         0.007804
#
#                          RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanAvg4Price                        -0.017486
#
#                          RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanAvg4Price                                    0.273278
#
#                          RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:MeanAvg4Price                                    0.173408
#
#                          RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:MeanAvg4Price                                    0.121242
#
#                          RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanAvg4Price                                    0.090679
#
#                          VolumeWeightedPctChange[t - 1]
# PctChange:MeanAvg4Price                        0.279725
#
# [1 rows x 97 columns]

# %%
find_most_correlated_features(single_stock, pct_change_of('MeanAvg4Price'))
# Out:
#                                             PctChange:MeanAvg4Price   AbsCorr
# AdjustedPctChange[t - 1]                                   0.648615  0.648615
# AdjLogReturn:LastEndPrice[t - 1]                           0.648611  0.648611
# F1[t - 1]                                                  0.594027  0.594027
# H1@WithNorm(MeanEndPrice)[t - 1]                           0.593925  0.593925
# RevPctChange[t - 1]:LastEndPrice                           0.545623  0.545623
# Direction2[t - 1]                                          0.545182  0.545182
# F2[t - 1]                                                  0.500112  0.500112
# Direction1[t - 1]                                          0.499097  0.499097
# F3[t - 1]                                                  0.497522  0.497522
# G1[t - 1]                                                  0.426857  0.426857
# F8[t - 1]                                                  0.396958  0.396958
# RevPctChange[t - 2]:LastEndPrice                           0.382551  0.382551
# F6[t - 1]                                                  0.357200  0.357200
# G3[t - 1]                                                  0.345520  0.345520
# G2[t - 1]                                                  0.340961  0.340961
# F7[t - 1]                                                  0.337546  0.337546
# VolumeWeightedPctChange[t - 1]                             0.279725  0.279725
# RevPctChange[t - 1]:VolumeWeightedEndPrice                 0.273278  0.273278
# G4[t - 1]                                                  0.262551  0.262551
# PctChange:LastEndPrice[t - 1]                              0.260451  0.260451
# RevPctChange[t - 1]:MeanEndPrice                           0.246160  0.246160
# RevPctChange[t - 1]:MeanMaxMinPrice                        0.237190  0.237190
# RevPctChange[t - 1]:MeanAvg4Price                          0.237016  0.237016
# RevPctChange[t - 1]:MeanStartEndPrice                      0.236824  0.236824
# RevPctChange[t - 1]:MedianEndPrice                         0.223581  0.223581
# RevPctChange[t - 1]:MaxPrice                               0.218768  0.218768
# RevPctChange[t - 1]:MinPrice                               0.214373  0.214373
# RevPctChange[t - 2]:VolumeWeightedEndPrice                 0.173408  0.173408
# RevPctChange[t - 2]:MinPrice                               0.166215  0.166215
# RevPctChange[t - 2]:MeanEndPrice                           0.152325  0.152325
# RevPctChange[t - 2]:MeanMaxMinPrice                        0.147126  0.147126
# RevPctChange[t - 2]:MeanAvg4Price                          0.146701  0.146701
# RevPctChange[t - 2]:MeanStartEndPrice                      0.146270  0.146270
# RevPctChange[t - 2]:MedianEndPrice                         0.145133  0.145133
# PctChange:VolumeWeightedEndPrice[t - 1]                    0.132772  0.132772
# RevPctChange[t - 2]:MaxPrice                               0.128987  0.128987
# PctChange:MeanEndPrice[t - 1]                              0.121603  0.121603
# PctChange:MeanMaxMinPrice[t - 1]                           0.116762  0.116762
# PctChange:MeanAvg4Price[t - 1]                             0.116700  0.116700
# PctChange:MeanStartEndPrice[t - 1]                         0.116626  0.116626
# PctChange:MaxPrice[t - 1]                                  0.114912  0.114912
# PctChange:MedianEndPrice[t - 1]                            0.114374  0.114374
# PctChange:MinPrice[t - 1]                                  0.106973  0.106973
# F4[t - 1]                                                  0.100365  0.100365
# F5[t - 1]                                                  0.098164  0.098164
# RevPctChange[t - 2]:StdEndPrice                           -0.036812  0.036812
# RevPctChange[t - 1]:FirstStartPrice                       -0.021477  0.021477
# PctChange:Direction1[t - 1]                               -0.021307  0.021307
# PctChange:Direction2[t - 1]                               -0.019160  0.019160
# RevPctChange[t - 1]:Direction2                            -0.018997  0.018997
# H1@WithNorm(MeanEndPrice)[t - 2]                          -0.016041  0.016041
# PctChange:StdEndPrice[t - 1]                               0.013559  0.013559
# RevPctChange[t - 2]:FirstStartPrice                       -0.011718  0.011718
# RevPctChange[t - 1]:Direction1                            -0.006752  0.006752
# PctChange:FirstStartPrice[t - 1]                           0.003496  0.003496
# RevPctChange[t - 2]:Direction1                             0.003026  0.003026
# RevPctChange[t - 2]:Direction2                             0.002136  0.002136
# RevPctChange[t - 1]:StdEndPrice                            0.000075  0.000075

# %%
corr_pct_change(single_stock, 'MeanMaxMinPrice')
# Out:
#                            Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# PctChange:MeanMaxMinPrice           0.498263           0.544435    0.59389
#
#                            F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  \
# PctChange:MeanMaxMinPrice   0.499274   0.496686   0.100764   0.098704
#
#                            F6[t - 1]  F7[t - 1]  F8[t - 1]  ...  \
# PctChange:MeanMaxMinPrice   0.356966   0.337818   0.397218  ...
#
#                            RevPctChange[t - 4]:Direction2  \
# PctChange:MeanMaxMinPrice                        0.007842
#
#                            RevPctChange[t - 1]:StdEndPrice  \
# PctChange:MeanMaxMinPrice                         0.000264
#
#                            RevPctChange[t - 2]:StdEndPrice  \
# PctChange:MeanMaxMinPrice                        -0.036838
#
#                            RevPctChange[t - 3]:StdEndPrice  \
# PctChange:MeanMaxMinPrice                         0.007853
#
#                            RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanMaxMinPrice                         -0.01757
#
#                            RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanMaxMinPrice                                    0.272533
#
#                            RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:MeanMaxMinPrice                                    0.172921
#
#                            RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:MeanMaxMinPrice                                    0.120676
#
#                            RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanMaxMinPrice                                    0.090292
#
#                            VolumeWeightedPctChange[t - 1]
# PctChange:MeanMaxMinPrice                        0.278972
#
# [1 rows x 97 columns]

# %%
corr_pct_change(single_stock, 'MeanStartEndPrice')
# Out:
#                              Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# PctChange:MeanStartEndPrice           0.499896           0.545891    0.59412
#
#                              F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  \
# PctChange:MeanStartEndPrice   0.500914   0.498324   0.099959   0.097617
#
#                              F6[t - 1]  F7[t - 1]  F8[t - 1]  ...  \
# PctChange:MeanStartEndPrice    0.35741   0.337251   0.396669  ...
#
#                              RevPctChange[t - 4]:Direction2  \
# PctChange:MeanStartEndPrice                        0.008082
#
#                              RevPctChange[t - 1]:StdEndPrice  \
# PctChange:MeanStartEndPrice                        -0.000114
#
#                              RevPctChange[t - 2]:StdEndPrice  \
# PctChange:MeanStartEndPrice                        -0.036783
#
#                              RevPctChange[t - 3]:StdEndPrice  \
# PctChange:MeanStartEndPrice                         0.007755
#
#                              RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanStartEndPrice                        -0.017401
#
#                              RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanStartEndPrice                                    0.274004
#
#                              RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:MeanStartEndPrice                                    0.173883
#
#                              RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:MeanStartEndPrice                                    0.121801
#
#                              RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanStartEndPrice                                    0.091061
#
#                              VolumeWeightedPctChange[t - 1]
# PctChange:MeanStartEndPrice                        0.280448
#
# [1 rows x 97 columns]

# %%
corr_pct_change(single_stock, 'MeanEndPrice')
# Out:
#                         Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# PctChange:MeanEndPrice           0.483451           0.526626   0.578251
#
#                         F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  \
# PctChange:MeanEndPrice   0.484426   0.481941   0.100102   0.096647   0.346744
#
#                         F7[t - 1]  F8[t - 1]  ...  \
# PctChange:MeanEndPrice   0.328076   0.386489  ...
#
#                         RevPctChange[t - 4]:Direction2  \
# PctChange:MeanEndPrice                         0.00797
#
#                         RevPctChange[t - 1]:StdEndPrice  \
# PctChange:MeanEndPrice                         0.001267
#
#                         RevPctChange[t - 2]:StdEndPrice  \
# PctChange:MeanEndPrice                         -0.03703
#
#                         RevPctChange[t - 3]:StdEndPrice  \
# PctChange:MeanEndPrice                         0.009331
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanEndPrice                        -0.017346
#
#                         RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice                                    0.261489
#
#                         RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice                                    0.165408
#
#                         RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice                                    0.114751
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice                                     0.08554
#
#                         VolumeWeightedPctChange[t - 1]
# PctChange:MeanEndPrice                        0.267774
#
# [1 rows x 97 columns]

# %%
corr_pct_change(single_stock, 'MedianEndPrice')
# Out:
#                           Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# PctChange:MedianEndPrice            0.43313           0.495696   0.531789
#
#                           F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  \
# PctChange:MedianEndPrice   0.434237   0.431455   0.103161   0.099751
#
#                           F6[t - 1]  F7[t - 1]  F8[t - 1]  ...  \
# PctChange:MedianEndPrice   0.333383   0.314047   0.375251  ...
#
#                           RevPctChange[t - 4]:Direction2  \
# PctChange:MedianEndPrice                        0.003766
#
#                           RevPctChange[t - 1]:StdEndPrice  \
# PctChange:MedianEndPrice                        -0.001568
#
#                           RevPctChange[t - 2]:StdEndPrice  \
# PctChange:MedianEndPrice                        -0.036419
#
#                           RevPctChange[t - 3]:StdEndPrice  \
# PctChange:MedianEndPrice                         0.017188
#
#                           RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MedianEndPrice                        -0.017327
#
#                           RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MedianEndPrice                                    0.231907
#
#                           RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:MedianEndPrice                                    0.146785
#
#                           RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:MedianEndPrice                                    0.102032
#
#                           RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MedianEndPrice                                    0.075265
#
#                           VolumeWeightedPctChange[t - 1]
# PctChange:MedianEndPrice                         0.25105
#
# [1 rows x 97 columns]

# %%
corr_pct_change(single_stock, 'VolumeWeightedEndPrice')
# Out:
#                                   Direction1[t - 1]  Direction2[t - 1]  \
# PctChange:VolumeWeightedEndPrice            0.40708           0.465904
#
#                                   F1[t - 1]  F2[t - 1]  F3[t - 1]  F4[t - 1]  \
# PctChange:VolumeWeightedEndPrice   0.517969   0.408149   0.405454   0.102325
#
#                                   F5[t - 1]  F6[t - 1]  F7[t - 1]  F8[t - 1]  \
# PctChange:VolumeWeightedEndPrice   0.092331   0.321097   0.313636   0.355343
#
#                                   ...  RevPctChange[t - 4]:Direction2  \
# PctChange:VolumeWeightedEndPrice  ...                        0.007447
#
#                                   RevPctChange[t - 1]:StdEndPrice  \
# PctChange:VolumeWeightedEndPrice                         0.005583
#
#                                   RevPctChange[t - 2]:StdEndPrice  \
# PctChange:VolumeWeightedEndPrice                        -0.036474
#
#                                   RevPctChange[t - 3]:StdEndPrice  \
# PctChange:VolumeWeightedEndPrice                         0.014437
#
#                                   RevPctChange[t - 4]:StdEndPrice  \
# PctChange:VolumeWeightedEndPrice                        -0.010864
#
#                                   RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:VolumeWeightedEndPrice                                    0.201354
#
#                                   RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# PctChange:VolumeWeightedEndPrice                                    0.123107
#
#                                   RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# PctChange:VolumeWeightedEndPrice                                    0.076505
#
#                                   RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:VolumeWeightedEndPrice                                    0.054892
#
#                                   VolumeWeightedPctChange[t - 1]
# PctChange:VolumeWeightedEndPrice                        0.223231
#
# [1 rows x 97 columns]

# %%
correlation_with_feature(single_stock, 'MeanPctChangeV2')
# Out:
#                  Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  F2[t - 1]  \
# MeanPctChangeV2          -0.031991          -0.045596   -0.04144  -0.032153
#
#                  F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  F7[t - 1]  \
# MeanPctChangeV2  -0.031811   0.023188  -0.014245  -0.022885  -0.022381
#
#                  F8[t - 1]  ...  RevPctChange[t - 4]:Direction2  \
# MeanPctChangeV2  -0.019361  ...                       -0.009426
#
#                  RevPctChange[t - 1]:StdEndPrice  \
# MeanPctChangeV2                         0.016292
#
#                  RevPctChange[t - 2]:StdEndPrice  \
# MeanPctChangeV2                        -0.040286
#
#                  RevPctChange[t - 3]:StdEndPrice  \
# MeanPctChangeV2                         0.028166
#
#                  RevPctChange[t - 4]:StdEndPrice  \
# MeanPctChangeV2                        -0.019766
#
#                  RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# MeanPctChangeV2                                   -0.009845
#
#                  RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# MeanPctChangeV2                                   -0.026365
#
#                  RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# MeanPctChangeV2                                   -0.041061
#
#                  RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# MeanPctChangeV2                                   -0.028729
#
#                  VolumeWeightedPctChange[t - 1]
# MeanPctChangeV2                       -0.024427
#
# [1 rows x 96 columns]

# %%
find_most_correlated_features(single_stock, 'MeanPctChangeV2')
# Out:
#                                             MeanPctChangeV2   AbsCorr
# G4[t - 1]                                         -0.063230  0.063230
# G2[t - 1]                                         -0.062256  0.062256
# G3[t - 1]                                         -0.059414  0.059414
# AdjLogReturn:LastEndPrice[t - 1]                  -0.056929  0.056929
# AdjustedPctChange[t - 1]                          -0.056923  0.056923
# G1[t - 1]                                         -0.053496  0.053496
# Direction2[t - 1]                                 -0.045596  0.045596
# RevPctChange[t - 1]:LastEndPrice                  -0.043364  0.043364
# F1[t - 1]                                         -0.041440  0.041440
# H1@WithNorm(MeanEndPrice)[t - 1]                  -0.041382  0.041382
# RevPctChange[t - 2]:StdEndPrice                   -0.040286  0.040286
# RevPctChange[t - 2]:LastEndPrice                  -0.039042  0.039042
# RevPctChange[t - 2]:MaxPrice                      -0.037298  0.037298
# PctChange:MedianEndPrice[t - 1]                    0.035520  0.035520
# PctChange:MeanEndPrice[t - 1]                      0.032675  0.032675
# F2[t - 1]                                         -0.032153  0.032153
# Direction1[t - 1]                                 -0.031991  0.031991
# PctChange:StdEndPrice[t - 1]                       0.031986  0.031986
# F3[t - 1]                                         -0.031811  0.031811
# PctChange:MeanStartEndPrice[t - 1]                 0.031624  0.031624
# PctChange:MeanAvg4Price[t - 1]                     0.031601  0.031601
# PctChange:MeanMaxMinPrice[t - 1]                   0.031575  0.031575
# PctChange:VolumeWeightedEndPrice[t - 1]            0.031453  0.031453
# RevPctChange[t - 1]:FirstStartPrice               -0.028884  0.028884
# RevPctChange[t - 2]:VolumeWeightedEndPrice        -0.026365  0.026365
# VolumeWeightedPctChange[t - 1]                    -0.024427  0.024427
# RevPctChange[t - 2]:MeanEndPrice                  -0.023796  0.023796
# RevPctChange[t - 2]:MeanStartEndPrice             -0.023460  0.023460
# RevPctChange[t - 2]:MeanAvg4Price                 -0.023324  0.023324
# F4[t - 1]                                          0.023188  0.023188
# RevPctChange[t - 2]:MeanMaxMinPrice               -0.023187  0.023187
# RevPctChange[t - 1]:MaxPrice                      -0.022937  0.022937
# F6[t - 1]                                         -0.022885  0.022885
# F7[t - 1]                                         -0.022381  0.022381
# PctChange:Direction1[t - 1]                        0.022045  0.022045
# PctChange:MaxPrice[t - 1]                          0.021680  0.021680
# RevPctChange[t - 1]:MinPrice                      -0.021157  0.021157
# RevPctChange[t - 2]:MedianEndPrice                -0.020154  0.020154
# F8[t - 1]                                         -0.019361  0.019361
# PctChange:Direction2[t - 1]                        0.018039  0.018039
# RevPctChange[t - 1]:StdEndPrice                    0.016292  0.016292
# F5[t - 1]                                         -0.014245  0.014245
# PctChange:MinPrice[t - 1]                          0.013596  0.013596
# RevPctChange[t - 1]:Direction1                    -0.013045  0.013045
# RevPctChange[t - 1]:Direction2                    -0.010306  0.010306
# H1@WithNorm(MeanEndPrice)[t - 2]                  -0.010220  0.010220
# RevPctChange[t - 1]:VolumeWeightedEndPrice        -0.009845  0.009845
# RevPctChange[t - 2]:MinPrice                      -0.008578  0.008578
# RevPctChange[t - 2]:Direction2                     0.008359  0.008359
# RevPctChange[t - 1]:MeanEndPrice                  -0.007801  0.007801
# RevPctChange[t - 1]:MeanMaxMinPrice               -0.007215  0.007215
# RevPctChange[t - 1]:MeanAvg4Price                 -0.007151  0.007151
# RevPctChange[t - 1]:MeanStartEndPrice             -0.007086  0.007086
# RevPctChange[t - 2]:Direction1                     0.006967  0.006967
# RevPctChange[t - 2]:FirstStartPrice               -0.005815  0.005815
# PctChange:FirstStartPrice[t - 1]                   0.005598  0.005598
# PctChange:LastEndPrice[t - 1]                      0.005375  0.005375
# RevPctChange[t - 1]:MedianEndPrice                -0.000717  0.000717

# %% [markdown]
# Let us settle for the moment on the 'MeanEndPrice', and compute the correlations over multiple intervals

# %%
# some of the better features
x_features = [
    'AdjustedPctChange[t - 1]',
    'F1[t - 1]',
    'H1@WithNorm(MeanEndPrice)[t - 1]',
    'RevPctChange[t - 1]:LastEndPrice',
    'F2[t - 1]',
    'Direction2[t - 1]',
    'F3[t - 1]',
    'G1[t - 1]',
    'G3[t - 1]',
    'PctChange:LastEndPrice[t - 1]',
    'RevPctChange[t - 2]:LastEndPrice',
    'F6[t - 1]',
    'G2[t - 1]',
    'F7[t - 1]',
    'G4[t - 1]',
    'RevPctChange[t - 1]:VolumeWeightedEndPrice',
    'RevPctChange[t - 1]:MinPrice',
    'RevPctChange[t - 1]:MeanEndPrice',
    'RevPctChange[t - 1]:MeanMaxMinPrice',
    'RevPctChange[t - 1]:MeanAvg4Price',
    'RevPctChange[t - 1]:MeanStartEndPrice',
    'RevPctChange[t - 1]:MaxPrice']

# %%
intervals = ['1Min', '2Min', '3Min', '4Min', '5Min', '6Min', '7Min', '8Min', '9Min', '10Min', 
             '15Min', '30Min', '60Min', '120Min', '180Min', '240Min',
             '1D', '2D', '1W', '2W']
def corr_over_intervals(stock):
    results = []
    for interval in intervals:
        single_stock = prepare_single_stock(stock, interval)
        cr = corr_pct_change(single_stock, 'MeanEndPrice')
        cr.index = [cr.index[0] + "@" + interval]
        results.append(cr)
    return pd.concat(results)

# %%
corr_over_intervals('BMW')[x_features]
# Out:
#                                AdjustedPctChange[t - 1]  F1[t - 1]  \
# PctChange:MeanEndPrice@1Min                         NaN  -0.040016
# PctChange:MeanEndPrice@2Min                    0.342471   0.289739
# PctChange:MeanEndPrice@3Min                    0.551271   0.495723
# PctChange:MeanEndPrice@4Min                    0.566814   0.525967
# PctChange:MeanEndPrice@5Min                    0.565416   0.531774
# PctChange:MeanEndPrice@6Min                    0.590399   0.555696
# PctChange:MeanEndPrice@7Min                    0.625876   0.591994
# PctChange:MeanEndPrice@8Min                    0.630653   0.594318
# PctChange:MeanEndPrice@9Min                    0.618434   0.579562
# PctChange:MeanEndPrice@10Min                   0.614705   0.574660
# PctChange:MeanEndPrice@15Min                   0.654117   0.602978
# PctChange:MeanEndPrice@30Min                   0.658903   0.613942
# PctChange:MeanEndPrice@60Min                   0.694655   0.649276
# PctChange:MeanEndPrice@120Min                  0.701747   0.636728
# PctChange:MeanEndPrice@180Min                  0.695476   0.648003
# PctChange:MeanEndPrice@240Min                  0.733977   0.632396
# PctChange:MeanEndPrice@1D                      0.426504   0.396335
# PctChange:MeanEndPrice@2D                      0.559142   0.528476
# PctChange:MeanEndPrice@1W                      0.672781   0.644818
# PctChange:MeanEndPrice@2W                      0.766301   0.780059
#
#                                H1@WithNorm(MeanEndPrice)[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.040016
# PctChange:MeanEndPrice@2Min                            0.289734
# PctChange:MeanEndPrice@3Min                            0.495199
# PctChange:MeanEndPrice@4Min                            0.525993
# PctChange:MeanEndPrice@5Min                            0.531898
# PctChange:MeanEndPrice@6Min                            0.555851
# PctChange:MeanEndPrice@7Min                            0.592208
# PctChange:MeanEndPrice@8Min                            0.594350
# PctChange:MeanEndPrice@9Min                            0.579671
# PctChange:MeanEndPrice@10Min                           0.574693
# PctChange:MeanEndPrice@15Min                           0.602929
# PctChange:MeanEndPrice@30Min                           0.613955
# PctChange:MeanEndPrice@60Min                           0.649291
# PctChange:MeanEndPrice@120Min                          0.637069
# PctChange:MeanEndPrice@180Min                          0.648012
# PctChange:MeanEndPrice@240Min                          0.632631
# PctChange:MeanEndPrice@1D                              0.396102
# PctChange:MeanEndPrice@2D                              0.527267
# PctChange:MeanEndPrice@1W                              0.643178
# PctChange:MeanEndPrice@2W                              0.775115
#
#                                RevPctChange[t - 1]:LastEndPrice  F2[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.057669  -0.044060
# PctChange:MeanEndPrice@2Min                            0.225450   0.244871
# PctChange:MeanEndPrice@3Min                            0.368611   0.441762
# PctChange:MeanEndPrice@4Min                            0.430283   0.462232
# PctChange:MeanEndPrice@5Min                            0.430781   0.455919
# PctChange:MeanEndPrice@6Min                            0.467702   0.477667
# PctChange:MeanEndPrice@7Min                            0.510106   0.523547
# PctChange:MeanEndPrice@8Min                            0.515764   0.515287
# PctChange:MeanEndPrice@9Min                            0.496090   0.501663
# PctChange:MeanEndPrice@10Min                           0.483943   0.481906
# PctChange:MeanEndPrice@15Min                           0.543033   0.508436
# PctChange:MeanEndPrice@30Min                           0.525468   0.507088
# PctChange:MeanEndPrice@60Min                           0.582784   0.567457
# PctChange:MeanEndPrice@120Min                          0.605349   0.557808
# PctChange:MeanEndPrice@180Min                          0.600194   0.548924
# PctChange:MeanEndPrice@240Min                          0.657055   0.476532
# PctChange:MeanEndPrice@1D                              0.237291   0.269173
# PctChange:MeanEndPrice@2D                              0.420302   0.473881
# PctChange:MeanEndPrice@1W                              0.499140   0.571495
# PctChange:MeanEndPrice@2W                              0.592554   0.629207
#
#                                Direction2[t - 1]  F3[t - 1]  G1[t - 1]  \
# PctChange:MeanEndPrice@1Min            -0.044253  -0.044180  -0.044115
# PctChange:MeanEndPrice@2Min             0.268131   0.244607   0.220126
# PctChange:MeanEndPrice@3Min             0.378296   0.442690   0.332429
# PctChange:MeanEndPrice@4Min             0.433443   0.461978   0.378099
# PctChange:MeanEndPrice@5Min             0.440793   0.454894   0.387331
# PctChange:MeanEndPrice@6Min             0.472083   0.476358   0.421592
# PctChange:MeanEndPrice@7Min             0.515200   0.522686   0.431648
# PctChange:MeanEndPrice@8Min             0.520891   0.513944   0.467379
# PctChange:MeanEndPrice@9Min             0.499425   0.500130   0.435211
# PctChange:MeanEndPrice@10Min            0.487570   0.480498   0.428700
# PctChange:MeanEndPrice@15Min            0.544789   0.506506   0.478727
# PctChange:MeanEndPrice@30Min            0.527821   0.505324   0.466055
# PctChange:MeanEndPrice@60Min            0.585198   0.565809   0.524512
# PctChange:MeanEndPrice@120Min           0.607802   0.556109   0.482065
# PctChange:MeanEndPrice@180Min           0.595142   0.547812   0.432629
# PctChange:MeanEndPrice@240Min           0.642651   0.475621   0.440196
# PctChange:MeanEndPrice@1D               0.401603   0.267961   0.130971
# PctChange:MeanEndPrice@2D               0.484741   0.474807   0.269731
# PctChange:MeanEndPrice@1W               0.584088   0.572422   0.130896
# PctChange:MeanEndPrice@2W               0.642983   0.629962   0.360310
#
#                                G3[t - 1]  PctChange:LastEndPrice[t - 1]  ...  \
# PctChange:MeanEndPrice@1Min    -0.040016                      -0.042200  ...
# PctChange:MeanEndPrice@2Min     0.188707                       0.136605  ...
# PctChange:MeanEndPrice@3Min     0.284448                       0.282670  ...
# PctChange:MeanEndPrice@4Min     0.324907                       0.290082  ...
# PctChange:MeanEndPrice@5Min     0.344720                       0.273967  ...
# PctChange:MeanEndPrice@6Min     0.366387                       0.289028  ...
# PctChange:MeanEndPrice@7Min     0.380510                       0.317882  ...
# PctChange:MeanEndPrice@8Min     0.406207                       0.307911  ...
# PctChange:MeanEndPrice@9Min     0.370102                       0.301639  ...
# PctChange:MeanEndPrice@10Min    0.375200                       0.286715  ...
# PctChange:MeanEndPrice@15Min    0.423081                       0.292065  ...
# PctChange:MeanEndPrice@30Min    0.399106                       0.291494  ...
# PctChange:MeanEndPrice@60Min    0.437473                       0.307664  ...
# PctChange:MeanEndPrice@120Min   0.371293                       0.283848  ...
# PctChange:MeanEndPrice@180Min   0.326240                       0.295896  ...
# PctChange:MeanEndPrice@240Min   0.291781                       0.197493  ...
# PctChange:MeanEndPrice@1D       0.119244                       0.144356  ...
# PctChange:MeanEndPrice@2D       0.192097                       0.377776  ...
# PctChange:MeanEndPrice@1W       0.177781                       0.496672  ...
# PctChange:MeanEndPrice@2W       0.380075                       0.581410  ...
#
#                                G2[t - 1]  F7[t - 1]  G4[t - 1]  \
# PctChange:MeanEndPrice@1Min    -0.025962  -0.027606  -0.024194
# PctChange:MeanEndPrice@2Min     0.167881   0.204659   0.136711
# PctChange:MeanEndPrice@3Min     0.243943   0.273013   0.202095
# PctChange:MeanEndPrice@4Min     0.286096   0.308451   0.233498
# PctChange:MeanEndPrice@5Min     0.300524   0.325587   0.250678
# PctChange:MeanEndPrice@6Min     0.313906   0.340947   0.262960
# PctChange:MeanEndPrice@7Min     0.323291   0.374064   0.270319
# PctChange:MeanEndPrice@8Min     0.334354   0.344175   0.273827
# PctChange:MeanEndPrice@9Min     0.329688   0.335445   0.268693
# PctChange:MeanEndPrice@10Min    0.332562   0.330276   0.265342
# PctChange:MeanEndPrice@15Min    0.349454   0.344299   0.276030
# PctChange:MeanEndPrice@30Min    0.337967   0.337137   0.251287
# PctChange:MeanEndPrice@60Min    0.368559   0.308067   0.262769
# PctChange:MeanEndPrice@120Min   0.313248   0.344561   0.215147
# PctChange:MeanEndPrice@180Min   0.285098   0.439516   0.190657
# PctChange:MeanEndPrice@240Min   0.269049   0.438542   0.154332
# PctChange:MeanEndPrice@1D       0.129605   0.222243   0.116906
# PctChange:MeanEndPrice@2D       0.152933  -0.008486   0.141785
# PctChange:MeanEndPrice@1W       0.058503   0.433556   0.149605
# PctChange:MeanEndPrice@2W       0.399271   0.456741   0.406928
#
#                                RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice@1Min                                     -0.057669
# PctChange:MeanEndPrice@2Min                                      0.116428
# PctChange:MeanEndPrice@3Min                                      0.196265
# PctChange:MeanEndPrice@4Min                                      0.216985
# PctChange:MeanEndPrice@5Min                                      0.209390
# PctChange:MeanEndPrice@6Min                                      0.227110
# PctChange:MeanEndPrice@7Min                                      0.250972
# PctChange:MeanEndPrice@8Min                                      0.249791
# PctChange:MeanEndPrice@9Min                                      0.237636
# PctChange:MeanEndPrice@10Min                                     0.219296
# PctChange:MeanEndPrice@15Min                                     0.258986
# PctChange:MeanEndPrice@30Min                                     0.240973
# PctChange:MeanEndPrice@60Min                                     0.275303
# PctChange:MeanEndPrice@120Min                                    0.269903
# PctChange:MeanEndPrice@180Min                                    0.186879
# PctChange:MeanEndPrice@240Min                                    0.252468
# PctChange:MeanEndPrice@1D                                        0.050948
# PctChange:MeanEndPrice@2D                                        0.330986
# PctChange:MeanEndPrice@1W                                        0.210228
# PctChange:MeanEndPrice@2W                                        0.040768
#
#                                RevPctChange[t - 1]:MinPrice  \
# PctChange:MeanEndPrice@1Min                       -0.038706
# PctChange:MeanEndPrice@2Min                        0.065166
# PctChange:MeanEndPrice@3Min                        0.134186
# PctChange:MeanEndPrice@4Min                        0.164556
# PctChange:MeanEndPrice@5Min                        0.150874
# PctChange:MeanEndPrice@6Min                        0.166189
# PctChange:MeanEndPrice@7Min                        0.193256
# PctChange:MeanEndPrice@8Min                        0.210597
# PctChange:MeanEndPrice@9Min                        0.203600
# PctChange:MeanEndPrice@10Min                       0.192938
# PctChange:MeanEndPrice@15Min                       0.232437
# PctChange:MeanEndPrice@30Min                       0.197967
# PctChange:MeanEndPrice@60Min                       0.267886
# PctChange:MeanEndPrice@120Min                      0.253878
# PctChange:MeanEndPrice@180Min                      0.190958
# PctChange:MeanEndPrice@240Min                      0.183441
# PctChange:MeanEndPrice@1D                          0.021564
# PctChange:MeanEndPrice@2D                          0.372762
# PctChange:MeanEndPrice@1W                          0.113029
# PctChange:MeanEndPrice@2W                          0.133575
#
#                                RevPctChange[t - 1]:MeanEndPrice  \
# PctChange:MeanEndPrice@1Min                           -0.057669
# PctChange:MeanEndPrice@2Min                            0.107801
# PctChange:MeanEndPrice@3Min                            0.156402
# PctChange:MeanEndPrice@4Min                            0.183966
# PctChange:MeanEndPrice@5Min                            0.196675
# PctChange:MeanEndPrice@6Min                            0.205975
# PctChange:MeanEndPrice@7Min                            0.213155
# PctChange:MeanEndPrice@8Min                            0.210900
# PctChange:MeanEndPrice@9Min                            0.207381
# PctChange:MeanEndPrice@10Min                           0.198068
# PctChange:MeanEndPrice@15Min                           0.222886
# PctChange:MeanEndPrice@30Min                           0.214357
# PctChange:MeanEndPrice@60Min                           0.239133
# PctChange:MeanEndPrice@120Min                          0.213852
# PctChange:MeanEndPrice@180Min                          0.130026
# PctChange:MeanEndPrice@240Min                          0.129210
# PctChange:MeanEndPrice@1D                              0.074884
# PctChange:MeanEndPrice@2D                              0.368392
# PctChange:MeanEndPrice@1W                              0.164668
# PctChange:MeanEndPrice@2W                              0.010775
#
#                                RevPctChange[t - 1]:MeanMaxMinPrice  \
# PctChange:MeanEndPrice@1Min                              -0.041413
# PctChange:MeanEndPrice@2Min                               0.054954
# PctChange:MeanEndPrice@3Min                               0.102394
# PctChange:MeanEndPrice@4Min                               0.133441
# PctChange:MeanEndPrice@5Min                               0.152193
# PctChange:MeanEndPrice@6Min                               0.165595
# PctChange:MeanEndPrice@7Min                               0.173343
# PctChange:MeanEndPrice@8Min                               0.177758
# PctChange:MeanEndPrice@9Min                               0.181254
# PctChange:MeanEndPrice@10Min                              0.174794
# PctChange:MeanEndPrice@15Min                              0.205639
# PctChange:MeanEndPrice@30Min                              0.206402
# PctChange:MeanEndPrice@60Min                              0.233871
# PctChange:MeanEndPrice@120Min                             0.211203
# PctChange:MeanEndPrice@180Min                             0.127243
# PctChange:MeanEndPrice@240Min                             0.127184
# PctChange:MeanEndPrice@1D                                 0.074113
# PctChange:MeanEndPrice@2D                                 0.367833
# PctChange:MeanEndPrice@1W                                 0.164904
# PctChange:MeanEndPrice@2W                                 0.010645
#
#                                RevPctChange[t - 1]:MeanAvg4Price  \
# PctChange:MeanEndPrice@1Min                            -0.041558
# PctChange:MeanEndPrice@2Min                             0.051866
# PctChange:MeanEndPrice@3Min                             0.099780
# PctChange:MeanEndPrice@4Min                             0.131541
# PctChange:MeanEndPrice@5Min                             0.151793
# PctChange:MeanEndPrice@6Min                             0.164571
# PctChange:MeanEndPrice@7Min                             0.172789
# PctChange:MeanEndPrice@8Min                             0.176773
# PctChange:MeanEndPrice@9Min                             0.180439
# PctChange:MeanEndPrice@10Min                            0.174223
# PctChange:MeanEndPrice@15Min                            0.205112
# PctChange:MeanEndPrice@30Min                            0.206200
# PctChange:MeanEndPrice@60Min                            0.233797
# PctChange:MeanEndPrice@120Min                           0.210943
# PctChange:MeanEndPrice@180Min                           0.127071
# PctChange:MeanEndPrice@240Min                           0.126991
# PctChange:MeanEndPrice@1D                               0.074368
# PctChange:MeanEndPrice@2D                               0.367627
# PctChange:MeanEndPrice@1W                               0.164882
# PctChange:MeanEndPrice@2W                               0.010675
#
#                                RevPctChange[t - 1]:MeanStartEndPrice  \
# PctChange:MeanEndPrice@1Min                                -0.040399
# PctChange:MeanEndPrice@2Min                                 0.048316
# PctChange:MeanEndPrice@3Min                                 0.096735
# PctChange:MeanEndPrice@4Min                                 0.129296
# PctChange:MeanEndPrice@5Min                                 0.151141
# PctChange:MeanEndPrice@6Min                                 0.163352
# PctChange:MeanEndPrice@7Min                                 0.172079
# PctChange:MeanEndPrice@8Min                                 0.175667
# PctChange:MeanEndPrice@9Min                                 0.179524
# PctChange:MeanEndPrice@10Min                                0.173575
# PctChange:MeanEndPrice@15Min                                0.204543
# PctChange:MeanEndPrice@30Min                                0.205986
# PctChange:MeanEndPrice@60Min                                0.233719
# PctChange:MeanEndPrice@120Min                               0.210682
# PctChange:MeanEndPrice@180Min                               0.126899
# PctChange:MeanEndPrice@240Min                               0.126798
# PctChange:MeanEndPrice@1D                                   0.074622
# PctChange:MeanEndPrice@2D                                   0.367420
# PctChange:MeanEndPrice@1W                                   0.164859
# PctChange:MeanEndPrice@2W                                   0.010706
#
#                                RevPctChange[t - 1]:MaxPrice
# PctChange:MeanEndPrice@1Min                       -0.035641
# PctChange:MeanEndPrice@2Min                        0.076487
# PctChange:MeanEndPrice@3Min                        0.129668
# PctChange:MeanEndPrice@4Min                        0.145654
# PctChange:MeanEndPrice@5Min                        0.161078
# PctChange:MeanEndPrice@6Min                        0.183919
# PctChange:MeanEndPrice@7Min                        0.196120
# PctChange:MeanEndPrice@8Min                        0.181611
# PctChange:MeanEndPrice@9Min                        0.184723
# PctChange:MeanEndPrice@10Min                       0.169566
# PctChange:MeanEndPrice@15Min                       0.202689
# PctChange:MeanEndPrice@30Min                       0.207997
# PctChange:MeanEndPrice@60Min                       0.217697
# PctChange:MeanEndPrice@120Min                      0.177215
# PctChange:MeanEndPrice@180Min                      0.146938
# PctChange:MeanEndPrice@240Min                      0.125898
# PctChange:MeanEndPrice@1D                          0.016199
# PctChange:MeanEndPrice@2D                          0.220406
# PctChange:MeanEndPrice@1W                          0.184723
# PctChange:MeanEndPrice@2W                          0.093234
#
# [20 rows x 22 columns]

# %%
corr_over_intervals('SIE')[x_features]
# Out:
#                                AdjustedPctChange[t - 1]  F1[t - 1]  \
# PctChange:MeanEndPrice@1Min                         NaN  -0.090224
# PctChange:MeanEndPrice@2Min                    0.301682   0.230909
# PctChange:MeanEndPrice@3Min                    0.567136   0.489287
# PctChange:MeanEndPrice@4Min                    0.590153   0.530668
# PctChange:MeanEndPrice@5Min                    0.574304   0.531847
# PctChange:MeanEndPrice@6Min                    0.598595   0.557032
# PctChange:MeanEndPrice@7Min                    0.580801   0.540116
# PctChange:MeanEndPrice@8Min                    0.620121   0.581521
# PctChange:MeanEndPrice@9Min                    0.623222   0.582490
# PctChange:MeanEndPrice@10Min                   0.615522   0.566007
# PctChange:MeanEndPrice@15Min                   0.627423   0.571155
# PctChange:MeanEndPrice@30Min                   0.632558   0.578251
# PctChange:MeanEndPrice@60Min                   0.686364   0.607140
# PctChange:MeanEndPrice@120Min                  0.717188   0.644845
# PctChange:MeanEndPrice@180Min                  0.641708   0.565835
# PctChange:MeanEndPrice@240Min                  0.748678   0.652954
# PctChange:MeanEndPrice@1D                      0.389065   0.370336
# PctChange:MeanEndPrice@2D                      0.591899   0.511921
# PctChange:MeanEndPrice@1W                      0.756558   0.737449
# PctChange:MeanEndPrice@2W                      0.833048   0.831545
#
#                                H1@WithNorm(MeanEndPrice)[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.090224
# PctChange:MeanEndPrice@2Min                            0.230919
# PctChange:MeanEndPrice@3Min                            0.489356
# PctChange:MeanEndPrice@4Min                            0.530669
# PctChange:MeanEndPrice@5Min                            0.531773
# PctChange:MeanEndPrice@6Min                            0.556929
# PctChange:MeanEndPrice@7Min                            0.540132
# PctChange:MeanEndPrice@8Min                            0.581395
# PctChange:MeanEndPrice@9Min                            0.582389
# PctChange:MeanEndPrice@10Min                           0.565975
# PctChange:MeanEndPrice@15Min                           0.571099
# PctChange:MeanEndPrice@30Min                           0.578156
# PctChange:MeanEndPrice@60Min                           0.606862
# PctChange:MeanEndPrice@120Min                          0.644335
# PctChange:MeanEndPrice@180Min                          0.565247
# PctChange:MeanEndPrice@240Min                          0.652171
# PctChange:MeanEndPrice@1D                              0.369850
# PctChange:MeanEndPrice@2D                              0.509516
# PctChange:MeanEndPrice@1W                              0.737329
# PctChange:MeanEndPrice@2W                              0.827141
#
#                                RevPctChange[t - 1]:LastEndPrice  F2[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.085911  -0.082159
# PctChange:MeanEndPrice@2Min                            0.193584   0.202880
# PctChange:MeanEndPrice@3Min                            0.342411   0.465839
# PctChange:MeanEndPrice@4Min                            0.409752   0.492846
# PctChange:MeanEndPrice@5Min                            0.430875   0.493123
# PctChange:MeanEndPrice@6Min                            0.463866   0.502388
# PctChange:MeanEndPrice@7Min                            0.475107   0.483449
# PctChange:MeanEndPrice@8Min                            0.508523   0.514442
# PctChange:MeanEndPrice@9Min                            0.498934   0.526482
# PctChange:MeanEndPrice@10Min                           0.499654   0.492738
# PctChange:MeanEndPrice@15Min                           0.523224   0.488795
# PctChange:MeanEndPrice@30Min                           0.527310   0.484426
# PctChange:MeanEndPrice@60Min                           0.604648   0.512574
# PctChange:MeanEndPrice@120Min                          0.623113   0.544067
# PctChange:MeanEndPrice@180Min                          0.577326   0.457533
# PctChange:MeanEndPrice@240Min                          0.718147   0.522449
# PctChange:MeanEndPrice@1D                              0.298933   0.309640
# PctChange:MeanEndPrice@2D                              0.464655   0.463501
# PctChange:MeanEndPrice@1W                              0.641032   0.679970
# PctChange:MeanEndPrice@2W                              0.701372   0.717937
#
#                                Direction2[t - 1]  F3[t - 1]  G1[t - 1]  \
# PctChange:MeanEndPrice@1Min            -0.082471  -0.082134  -0.082144
# PctChange:MeanEndPrice@2Min             0.233511   0.202869   0.144197
# PctChange:MeanEndPrice@3Min             0.355991   0.467812   0.239553
# PctChange:MeanEndPrice@4Min             0.421914   0.493727   0.292073
# PctChange:MeanEndPrice@5Min             0.443913   0.493072   0.322261
# PctChange:MeanEndPrice@6Min             0.472940   0.501710   0.347485
# PctChange:MeanEndPrice@7Min             0.499448   0.482672   0.327988
# PctChange:MeanEndPrice@8Min             0.512527   0.512973   0.388415
# PctChange:MeanEndPrice@9Min             0.504428   0.525521   0.364460
# PctChange:MeanEndPrice@10Min            0.504239   0.490857   0.381413
# PctChange:MeanEndPrice@15Min            0.523973   0.486416   0.405021
# PctChange:MeanEndPrice@30Min            0.526626   0.481941   0.404225
# PctChange:MeanEndPrice@60Min            0.606072   0.509169   0.424507
# PctChange:MeanEndPrice@120Min           0.623234   0.541958   0.332287
# PctChange:MeanEndPrice@180Min           0.578537   0.455081   0.213339
# PctChange:MeanEndPrice@240Min           0.719841   0.519891   0.107307
# PctChange:MeanEndPrice@1D               0.437879   0.308638   0.072500
# PctChange:MeanEndPrice@2D               0.565339   0.463288   0.112312
# PctChange:MeanEndPrice@1W               0.678081   0.678996   0.043031
# PctChange:MeanEndPrice@2W               0.720215   0.719283   0.057052
#
#                                G3[t - 1]  PctChange:LastEndPrice[t - 1]  ...  \
# PctChange:MeanEndPrice@1Min    -0.090224                      -0.063377  ...
# PctChange:MeanEndPrice@2Min     0.111798                       0.112306  ...
# PctChange:MeanEndPrice@3Min     0.194866                       0.280627  ...
# PctChange:MeanEndPrice@4Min     0.236732                       0.281313  ...
# PctChange:MeanEndPrice@5Min     0.268725                       0.271183  ...
# PctChange:MeanEndPrice@6Min     0.291706                       0.277257  ...
# PctChange:MeanEndPrice@7Min     0.272410                       0.272062  ...
# PctChange:MeanEndPrice@8Min     0.323499                       0.280601  ...
# PctChange:MeanEndPrice@9Min     0.304915                       0.290548  ...
# PctChange:MeanEndPrice@10Min    0.322332                       0.264453  ...
# PctChange:MeanEndPrice@15Min    0.332411                       0.250413  ...
# PctChange:MeanEndPrice@30Min    0.322880                       0.253447  ...
# PctChange:MeanEndPrice@60Min    0.324127                       0.257177  ...
# PctChange:MeanEndPrice@120Min   0.239049                       0.250666  ...
# PctChange:MeanEndPrice@180Min   0.131524                       0.232633  ...
# PctChange:MeanEndPrice@240Min   0.025242                       0.190099  ...
# PctChange:MeanEndPrice@1D       0.002706                       0.203752  ...
# PctChange:MeanEndPrice@2D       0.060119                       0.320824  ...
# PctChange:MeanEndPrice@1W       0.059629                       0.640412  ...
# PctChange:MeanEndPrice@2W      -0.009206                       0.687632  ...
#
#                                G2[t - 1]  F7[t - 1]  G4[t - 1]  \
# PctChange:MeanEndPrice@1Min    -0.078285  -0.051484  -0.088564
# PctChange:MeanEndPrice@2Min     0.109725   0.173531   0.069823
# PctChange:MeanEndPrice@3Min     0.193716   0.243119   0.142012
# PctChange:MeanEndPrice@4Min     0.237012   0.272101   0.174166
# PctChange:MeanEndPrice@5Min     0.267913   0.292105   0.202738
# PctChange:MeanEndPrice@6Min     0.287080   0.300238   0.223415
# PctChange:MeanEndPrice@7Min     0.284170   0.308659   0.206439
# PctChange:MeanEndPrice@8Min     0.318103   0.313624   0.242819
# PctChange:MeanEndPrice@9Min     0.312963   0.304046   0.244559
# PctChange:MeanEndPrice@10Min    0.315689   0.305738   0.244638
# PctChange:MeanEndPrice@15Min    0.328458   0.326040   0.252966
# PctChange:MeanEndPrice@30Min    0.322386   0.328076   0.244377
# PctChange:MeanEndPrice@60Min    0.350929   0.340335   0.259942
# PctChange:MeanEndPrice@120Min   0.302817   0.367969   0.224962
# PctChange:MeanEndPrice@180Min   0.199041   0.385694   0.114321
# PctChange:MeanEndPrice@240Min   0.122331   0.357899   0.050281
# PctChange:MeanEndPrice@1D       0.173451   0.222744   0.008701
# PctChange:MeanEndPrice@2D       0.162812   0.037132   0.051152
# PctChange:MeanEndPrice@1W      -0.089366   0.481892  -0.021781
# PctChange:MeanEndPrice@2W      -0.178759   0.500015  -0.144331
#
#                                RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice@1Min                                     -0.085911
# PctChange:MeanEndPrice@2Min                                      0.093480
# PctChange:MeanEndPrice@3Min                                      0.179563
# PctChange:MeanEndPrice@4Min                                      0.214838
# PctChange:MeanEndPrice@5Min                                      0.219473
# PctChange:MeanEndPrice@6Min                                      0.230445
# PctChange:MeanEndPrice@7Min                                      0.237626
# PctChange:MeanEndPrice@8Min                                      0.257305
# PctChange:MeanEndPrice@9Min                                      0.254540
# PctChange:MeanEndPrice@10Min                                     0.241467
# PctChange:MeanEndPrice@15Min                                     0.245331
# PctChange:MeanEndPrice@30Min                                     0.261489
# PctChange:MeanEndPrice@60Min                                     0.301226
# PctChange:MeanEndPrice@120Min                                    0.251374
# PctChange:MeanEndPrice@180Min                                    0.229021
# PctChange:MeanEndPrice@240Min                                    0.387777
# PctChange:MeanEndPrice@1D                                        0.150071
# PctChange:MeanEndPrice@2D                                        0.266031
# PctChange:MeanEndPrice@1W                                        0.327005
# PctChange:MeanEndPrice@2W                                        0.215234
#
#                                RevPctChange[t - 1]:MinPrice  \
# PctChange:MeanEndPrice@1Min                       -0.049432
# PctChange:MeanEndPrice@2Min                        0.059237
# PctChange:MeanEndPrice@3Min                        0.119608
# PctChange:MeanEndPrice@4Min                        0.157742
# PctChange:MeanEndPrice@5Min                        0.158246
# PctChange:MeanEndPrice@6Min                        0.182982
# PctChange:MeanEndPrice@7Min                        0.201766
# PctChange:MeanEndPrice@8Min                        0.215078
# PctChange:MeanEndPrice@9Min                        0.220449
# PctChange:MeanEndPrice@10Min                       0.210238
# PctChange:MeanEndPrice@15Min                       0.211400
# PctChange:MeanEndPrice@30Min                       0.205414
# PctChange:MeanEndPrice@60Min                       0.275617
# PctChange:MeanEndPrice@120Min                      0.214364
# PctChange:MeanEndPrice@180Min                      0.209580
# PctChange:MeanEndPrice@240Min                      0.204521
# PctChange:MeanEndPrice@1D                          0.142733
# PctChange:MeanEndPrice@2D                          0.432768
# PctChange:MeanEndPrice@1W                          0.399118
# PctChange:MeanEndPrice@2W                          0.375985
#
#                                RevPctChange[t - 1]:MeanEndPrice  \
# PctChange:MeanEndPrice@1Min                           -0.085911
# PctChange:MeanEndPrice@2Min                            0.083069
# PctChange:MeanEndPrice@3Min                            0.144509
# PctChange:MeanEndPrice@4Min                            0.172412
# PctChange:MeanEndPrice@5Min                            0.186510
# PctChange:MeanEndPrice@6Min                            0.198046
# PctChange:MeanEndPrice@7Min                            0.204463
# PctChange:MeanEndPrice@8Min                            0.220813
# PctChange:MeanEndPrice@9Min                            0.216911
# PctChange:MeanEndPrice@10Min                           0.213795
# PctChange:MeanEndPrice@15Min                           0.220279
# PctChange:MeanEndPrice@30Min                           0.235247
# PctChange:MeanEndPrice@60Min                           0.246020
# PctChange:MeanEndPrice@120Min                          0.191435
# PctChange:MeanEndPrice@180Min                          0.200713
# PctChange:MeanEndPrice@240Min                          0.343719
# PctChange:MeanEndPrice@1D                              0.180653
# PctChange:MeanEndPrice@2D                              0.234967
# PctChange:MeanEndPrice@1W                              0.275935
# PctChange:MeanEndPrice@2W                              0.170567
#
#                                RevPctChange[t - 1]:MeanMaxMinPrice  \
# PctChange:MeanEndPrice@1Min                              -0.052119
# PctChange:MeanEndPrice@2Min                               0.046689
# PctChange:MeanEndPrice@3Min                               0.098368
# PctChange:MeanEndPrice@4Min                               0.133051
# PctChange:MeanEndPrice@5Min                               0.147531
# PctChange:MeanEndPrice@6Min                               0.164598
# PctChange:MeanEndPrice@7Min                               0.175912
# PctChange:MeanEndPrice@8Min                               0.194119
# PctChange:MeanEndPrice@9Min                               0.193835
# PctChange:MeanEndPrice@10Min                              0.192759
# PctChange:MeanEndPrice@15Min                              0.204190
# PctChange:MeanEndPrice@30Min                              0.226809
# PctChange:MeanEndPrice@60Min                              0.241011
# PctChange:MeanEndPrice@120Min                             0.187258
# PctChange:MeanEndPrice@180Min                             0.197377
# PctChange:MeanEndPrice@240Min                             0.342207
# PctChange:MeanEndPrice@1D                                 0.181540
# PctChange:MeanEndPrice@2D                                 0.234851
# PctChange:MeanEndPrice@1W                                 0.275584
# PctChange:MeanEndPrice@2W                                 0.171013
#
#                                RevPctChange[t - 1]:MeanAvg4Price  \
# PctChange:MeanEndPrice@1Min                            -0.059140
# PctChange:MeanEndPrice@2Min                             0.043832
# PctChange:MeanEndPrice@3Min                             0.096647
# PctChange:MeanEndPrice@4Min                             0.131110
# PctChange:MeanEndPrice@5Min                             0.146439
# PctChange:MeanEndPrice@6Min                             0.163655
# PctChange:MeanEndPrice@7Min                             0.175371
# PctChange:MeanEndPrice@8Min                             0.193123
# PctChange:MeanEndPrice@9Min                             0.193237
# PctChange:MeanEndPrice@10Min                            0.192372
# PctChange:MeanEndPrice@15Min                            0.203853
# PctChange:MeanEndPrice@30Min                            0.226606
# PctChange:MeanEndPrice@60Min                            0.240642
# PctChange:MeanEndPrice@120Min                           0.187211
# PctChange:MeanEndPrice@180Min                           0.197268
# PctChange:MeanEndPrice@240Min                           0.342153
# PctChange:MeanEndPrice@1D                               0.180986
# PctChange:MeanEndPrice@2D                               0.234225
# PctChange:MeanEndPrice@1W                               0.275723
# PctChange:MeanEndPrice@2W                               0.170979
#
#                                RevPctChange[t - 1]:MeanStartEndPrice  \
# PctChange:MeanEndPrice@1Min                                -0.064718
# PctChange:MeanEndPrice@2Min                                 0.040555
# PctChange:MeanEndPrice@3Min                                 0.094445
# PctChange:MeanEndPrice@4Min                                 0.128759
# PctChange:MeanEndPrice@5Min                                 0.145044
# PctChange:MeanEndPrice@6Min                                 0.162469
# PctChange:MeanEndPrice@7Min                                 0.174649
# PctChange:MeanEndPrice@8Min                                 0.191955
# PctChange:MeanEndPrice@9Min                                 0.192508
# PctChange:MeanEndPrice@10Min                                0.191879
# PctChange:MeanEndPrice@15Min                                0.203463
# PctChange:MeanEndPrice@30Min                                0.226386
# PctChange:MeanEndPrice@60Min                                0.240268
# PctChange:MeanEndPrice@120Min                               0.187163
# PctChange:MeanEndPrice@180Min                               0.197159
# PctChange:MeanEndPrice@240Min                               0.342099
# PctChange:MeanEndPrice@1D                                   0.180429
# PctChange:MeanEndPrice@2D                                   0.233597
# PctChange:MeanEndPrice@1W                                   0.275861
# PctChange:MeanEndPrice@2W                                   0.170945
#
#                                RevPctChange[t - 1]:MaxPrice
# PctChange:MeanEndPrice@1Min                       -0.044420
# PctChange:MeanEndPrice@2Min                        0.063550
# PctChange:MeanEndPrice@3Min                        0.121027
# PctChange:MeanEndPrice@4Min                        0.148077
# PctChange:MeanEndPrice@5Min                        0.147374
# PctChange:MeanEndPrice@6Min                        0.162552
# PctChange:MeanEndPrice@7Min                        0.176317
# PctChange:MeanEndPrice@8Min                        0.186707
# PctChange:MeanEndPrice@9Min                        0.182340
# PctChange:MeanEndPrice@10Min                       0.177824
# PctChange:MeanEndPrice@15Min                       0.193396
# PctChange:MeanEndPrice@30Min                       0.209871
# PctChange:MeanEndPrice@60Min                       0.217155
# PctChange:MeanEndPrice@120Min                      0.241888
# PctChange:MeanEndPrice@180Min                      0.231707
# PctChange:MeanEndPrice@240Min                      0.435201
# PctChange:MeanEndPrice@1D                          0.023143
# PctChange:MeanEndPrice@2D                          0.107803
# PctChange:MeanEndPrice@1W                          0.176603
# PctChange:MeanEndPrice@2W                          0.162010
#
# [20 rows x 22 columns]

# %%
# corr_over_intervals('SAP')

# %% [markdown]
# The reasons for the strong correlations is due to averaging.
# We make an experiment to check the correlation with `MaxPrice` which uses only `MaxPrice`
# and `Direction` which uses only `EndPrice` and `StartPrice`.

# %%
single_stock = prepare_single_stock('BMW', '1D')
pd.DataFrame({
    'PctChange:MaxPrice': single_stock['PctChange:MaxPrice'],
    'Direction2[t + 1]': single_stock['Direction2'].shift(-1),   
    'Direction2[t - 0]': single_stock['Direction2'],        
    'Direction2[t - 1]': single_stock['Direction2[t - 1]'],
    'Direction2[t - 2]': single_stock['Direction2[t - 1]'].shift(1),
    'Direction2[t - 3]': single_stock['Direction2[t - 1]'].shift(2),
    'Direction2[t - 4]': single_stock['Direction2[t - 1]'].shift(3),
    'Direction2[t - 4]': single_stock['Direction2[t - 1]'].shift(4)    
}).corr()[['PctChange:MaxPrice']]
# Out:
#                     PctChange:MaxPrice
# PctChange:MaxPrice            1.000000
# Direction2[t + 1]            -0.040965
# Direction2[t - 0]             0.457563
# Direction2[t - 1]             0.522053
# Direction2[t - 2]             0.103093
# Direction2[t - 3]             0.060559
# Direction2[t - 4]            -0.088948

# %%
single_stock = prepare_single_stock('BMW', '1D')
pd.DataFrame({
    'PctChange:LastEndPrice': single_stock['PctChange:LastEndPrice'],
    'Direction2[t + 1]': single_stock['Direction2'].shift(-1),   
    'Direction2[t - 0]': single_stock['Direction2'],        
    'Direction2[t - 1]': single_stock['Direction2[t - 1]'],
    'Direction2[t - 2]': single_stock['Direction2[t - 1]'].shift(1),
    'Direction2[t - 3]': single_stock['Direction2[t - 1]'].shift(2),
    'Direction2[t - 4]': single_stock['Direction2[t - 1]'].shift(3),
    'Direction2[t - 4]': single_stock['Direction2[t - 1]'].shift(4)    
}).corr()[['PctChange:LastEndPrice']]
# Out:
#                         PctChange:LastEndPrice
# PctChange:LastEndPrice                1.000000
# Direction2[t + 1]                     0.037161
# Direction2[t - 0]                     0.764989
# Direction2[t - 1]                     0.165309
# Direction2[t - 2]                     0.171774
# Direction2[t - 3]                     0.015430
# Direction2[t - 4]                    -0.084145

# %% [markdown]
# The reason that there is no correlation between period `(t)` and `(t - 2)` is related to the normalization we do in percent change. We can verify this independently next.

# %%
single_stock = prepare_single_stock('BMW', '1D')
last_end_price = single_stock['PctChange:LastEndPrice']
pd.DataFrame({
    'PctChange:LastEndPrice': last_end_price,       
    'PctChange:LastEndPrice[t - 1]': last_end_price.shift(1),
    'PctChange:LastEndPrice[t - 2]': last_end_price.shift(2),
    'PctChange:LastEndPrice[t - 3]': last_end_price.shift(3),
    'PctChange:LastEndPrice[t - 4]': last_end_price.shift(4)    
}).corr()[['PctChange:LastEndPrice']]
# Out:
#                                PctChange:LastEndPrice
# PctChange:LastEndPrice                       1.000000
# PctChange:LastEndPrice[t - 1]                0.069811
# PctChange:LastEndPrice[t - 2]                0.061999
# PctChange:LastEndPrice[t - 3]                0.037790
# PctChange:LastEndPrice[t - 4]               -0.093435

# %% [markdown]
# Once we start normalizing the features in the same way, we find that past periods also exibit
# correlations to the present

# %%
single_stock = prepare_single_stock('BMW', '1D')
last_end_price = single_stock['PctChange:LastEndPrice']
pd.DataFrame({
    'PctChange:LastEndPrice': last_end_price,       
    rev_pct_change_of_at_t('LastEndPrice', 1): single_stock[rev_pct_change_of_at_t('LastEndPrice', 1)],
    rev_pct_change_of_at_t('LastEndPrice', 2): single_stock[rev_pct_change_of_at_t('LastEndPrice', 2)],
    rev_pct_change_of_at_t('LastEndPrice', 3): single_stock[rev_pct_change_of_at_t('LastEndPrice', 3)]
}).corr()[['PctChange:LastEndPrice']]
# Out:
#                                   PctChange:LastEndPrice
# PctChange:LastEndPrice                          1.000000
# RevPctChange[t - 1]:LastEndPrice                0.082298
# RevPctChange[t - 2]:LastEndPrice                0.138807
# RevPctChange[t - 3]:LastEndPrice                0.116341

# %%
single_stock = prepare_single_stock('BMW', '1D')
mean_end_price = single_stock['PctChange:MeanEndPrice']
pd.DataFrame({
    'PctChange:MeanEndPrice': mean_end_price,       
    rev_pct_change_of_at_t('MeanEndPrice', 1): single_stock[rev_pct_change_of_at_t('MeanEndPrice', 1)],
    rev_pct_change_of_at_t('MeanEndPrice', 2): single_stock[rev_pct_change_of_at_t('MeanEndPrice', 2)],
    rev_pct_change_of_at_t('MeanEndPrice', 3): single_stock[rev_pct_change_of_at_t('MeanEndPrice', 3)]
}).corr()[['PctChange:MeanEndPrice']]
# Out:
#                                   PctChange:MeanEndPrice
# PctChange:MeanEndPrice                          1.000000
# RevPctChange[t - 1]:MeanEndPrice                0.074884
# RevPctChange[t - 2]:MeanEndPrice                0.098395
# RevPctChange[t - 3]:MeanEndPrice                0.170181

# %% [markdown]
# If we experiment with the same feature, but normalized differently we:
# - are not going to see correlations beyond `(t - 1)` when different normalization is used
# - we may see correlations with the past when the same normalization is used

# %%
single_stock = prepare_single_stock('BMW', '1D')
mean_end_price = single_stock['PctChange:MeanEndPrice']
pd.DataFrame({
    'PctChange:MeanEndPrice': mean_end_price,       
    norm_feature('H1', 1, 'MeanEndPrice'): single_stock[norm_feature('H1', 1, 'MeanEndPrice')],
    norm_feature('H1', 2, 'MeanEndPrice'): single_stock[norm_feature('H1', 2, 'MeanEndPrice')],
    norm_feature('H1', 3, 'MeanEndPrice'): single_stock[norm_feature('H1', 3, 'MeanEndPrice')],
    norm_feature('H1', 4, 'MeanEndPrice'): single_stock[norm_feature('H1', 4, 'MeanEndPrice')],
    'F1[t - 1]': single_stock['F1[t - 1]'],
    'F1[t - 2]': single_stock['F1[t - 1]'].shift(1),
    'F1[t - 3]': single_stock['F1[t - 1]'].shift(2),
    'F1[t - 4]': single_stock['F1[t - 1]'].shift(3)  
}).corr()[['PctChange:MeanEndPrice']]
# Out:
#                                   PctChange:MeanEndPrice
# PctChange:MeanEndPrice                          1.000000
# H1@WithNorm(MeanEndPrice)[t - 1]                0.396102
# H1@WithNorm(MeanEndPrice)[t - 2]                0.024512
# H1@WithNorm(MeanEndPrice)[t - 3]               -0.083978
# H1@WithNorm(MeanEndPrice)[t - 4]                0.258168
# F1[t - 1]                                       0.396335
# F1[t - 2]                                       0.041163
# F1[t - 3]                                      -0.014884
# F1[t - 4]                                       0.059665

# %% [markdown]
# ## Log of return
# In their [demo notebook](https://github.com/googledatalab/notebooks/blob/master/samples/TensorFlow/Machine%20Learning%20with%20Financial%20Data.ipynb) Google Cloud computes a feature that they call log return. This feature is:
#
# ```
# log(Price:X[t]/Price:X[t - 1])
# ```
# for some version of price X.
#
# We explore this feature below. We find that when `Mean` of price is used, this feature correlates well
# with various predictors, but when the `Last` of price is used, this feature does not correlate very well

# %%
single_stock = prepare_single_stock('SIE', '30Min')
corr_log_return(single_stock, 'MeanEndPrice')
# Out:
#                         Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# LogReturn:MeanEndPrice           0.483406           0.526596   0.578146
#
#                         F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  \
# LogReturn:MeanEndPrice   0.484382   0.481897   0.099758   0.096859   0.346751
#
#                         F7[t - 1]  F8[t - 1]  ...  \
# LogReturn:MeanEndPrice    0.32796   0.386403  ...
#
#                         RevPctChange[t - 4]:Direction2  \
# LogReturn:MeanEndPrice                        0.007901
#
#                         RevPctChange[t - 1]:StdEndPrice  \
# LogReturn:MeanEndPrice                         0.001222
#
#                         RevPctChange[t - 2]:StdEndPrice  \
# LogReturn:MeanEndPrice                         -0.03723
#
#                         RevPctChange[t - 3]:StdEndPrice  \
# LogReturn:MeanEndPrice                         0.009178
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# LogReturn:MeanEndPrice                        -0.017552
#
#                         RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# LogReturn:MeanEndPrice                                    0.261486
#
#                         RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# LogReturn:MeanEndPrice                                    0.165445
#
#                         RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# LogReturn:MeanEndPrice                                    0.114805
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# LogReturn:MeanEndPrice                                    0.085632
#
#                         VolumeWeightedPctChange[t - 1]
# LogReturn:MeanEndPrice                        0.447735
#
# [1 rows x 96 columns]

# %%
single_stock = prepare_single_stock('SIE', '30Min')
corr_log_return(single_stock, 'LastEndPrice')
# Out:
#                         Direction1[t - 1]  Direction2[t - 1]  F1[t - 1]  \
# LogReturn:LastEndPrice          -0.014406            -0.0312  -0.028672
#
#                         F2[t - 1]  F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  \
# LogReturn:LastEndPrice   -0.01451  -0.014227   0.019149  -0.018149  -0.020512
#
#                         F7[t - 1]  F8[t - 1]  ...  \
# LogReturn:LastEndPrice  -0.030164  -0.013356  ...
#
#                         RevPctChange[t - 4]:Direction2  \
# LogReturn:LastEndPrice                       -0.025579
#
#                         RevPctChange[t - 1]:StdEndPrice  \
# LogReturn:LastEndPrice                         0.004343
#
#                         RevPctChange[t - 2]:StdEndPrice  \
# LogReturn:LastEndPrice                        -0.036127
#
#                         RevPctChange[t - 3]:StdEndPrice  \
# LogReturn:LastEndPrice                         0.031563
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# LogReturn:LastEndPrice                        -0.015164
#
#                         RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# LogReturn:LastEndPrice                                     0.01188
#
#                         RevPctChange[t - 2]:VolumeWeightedEndPrice  \
# LogReturn:LastEndPrice                                   -0.005545
#
#                         RevPctChange[t - 3]:VolumeWeightedEndPrice  \
# LogReturn:LastEndPrice                                   -0.032484
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# LogReturn:LastEndPrice                                   -0.018885
#
#                         VolumeWeightedPctChange[t - 1]
# LogReturn:LastEndPrice                       -0.009704
#
# [1 rows x 96 columns]

# %% [markdown]
# When we examine correlations of LogReturn we find that beyond `(t - 1)` there are no correlations.
# Google cloud also reports the same. As we explained, the reason is due to different normalizaiton
# in different periods.

# %%
single_stock = prepare_single_stock('SIE', '30Min')
mean_end_price = single_stock['LogReturn:MeanEndPrice']
pd.DataFrame({
    'LogReturn:MeanEndPrice': mean_end_price,     
    'LogReturn:MeanEndPrice[t - 1]': single_stock['LogReturn:MeanEndPrice[t - 1]'],
    'LogReturn:MeanEndPrice[t - 2]': single_stock['LogReturn:MeanEndPrice[t - 1]'].shift(1),
    'LogReturn:MeanEndPrice[t - 3]': single_stock['LogReturn:MeanEndPrice[t - 1]'].shift(2),
    'LogReturn:MeanEndPrice[t - 4]': single_stock['LogReturn:MeanEndPrice[t - 1]'].shift(3)  
}).corr()[['LogReturn:MeanEndPrice']]
# Out:
#                                LogReturn:MeanEndPrice
# LogReturn:MeanEndPrice                       1.000000
# LogReturn:MeanEndPrice[t - 1]                0.235328
# LogReturn:MeanEndPrice[t - 2]               -0.006197
# LogReturn:MeanEndPrice[t - 3]               -0.032370
# LogReturn:MeanEndPrice[t - 4]               -0.021452

# %% [markdown]
# ## On the relationship between percent change and log return

# %% [markdown]
# Some people prefer to model percent change, while others prefer to model log return.
# We find that both a suspiciously correlated. It turns that there is an approximate
# mathematical equality that relates them
#
# ```
# log(a/b) = log[ (b + (a - b))/b ] = log(1 + pct_change) = pct_change,
# where pct_change = (a - b)/b
#
# log(1 + x) = x is an approximate equality when x is close to zero
# ```

# %% [markdown]
# # The variance of predicted features

# %% [markdown]
# Below we study the variance of a number of functions:
#
# ```
# func = (price - anchor)/anchor
# ```
# for different choices of price and anchor.
#
# ```
# end to end: (end_price[t] - end_price[t - 1])/end_price[t - 1]
# end to mean: (end_price[t] - mean_price[t - 1])/mean_price[t - 1]
# mean to end: (mean_price[t] - end_price[t - 1])/end_price[t - 1]
# mean to mean: (mean_price[t] - mean_price[t - 1])/mean_price[t - 1]
# mean to prev mean: (mean_price[t] - mean_price[t - 2])/mean_price[t - 2]
# ```
#
# The idea is that we use the following method to estimate mean price in minutes 15 to 20.
# - estimate the mean price in minutes 10 to 15, call it `M[1]`
# - estimate the mean price in minutes 10 to 20, call it `M[2]`
# - compute `M[2] - M[1]`, the second minus the first
#
# ## Some observations
#
# - As the anchor goes further back in time from the predicted price, the variance increases

# %%
intervals = ['1Min', '2Min', '3Min', '4Min', '5Min', '6Min', '7Min', '8Min', '9Min', '10Min', 
             '15Min', '30Min', '60Min', '120Min', '180Min', '240Min',
             '1D', '2D', '1W', '2W', '1M', '2M', '3M', '6M']
rows = []
for i in intervals:
    single_stock = prepare_single_stock('SIE', i)
    e = single_stock['LastEndPrice']
    n = single_stock['LastEndPrice'].shift(1)
    end_to_end = (e - n)/n
    
    m = single_stock['MeanAvg4Price']
    end_to_mean = (e - m.shift(1))/m.shift(1)  
    mean_to_mean = (m - m.shift(1))/m.shift(1)
    mean_to_prev_mean = (m - m.shift(2))/m.shift(2) 
    mean_to_end = (m - e)/e
    rows.append((i, end_to_end.std(), end_to_mean.std(), mean_to_mean.std(), mean_to_prev_mean.std(), mean_to_end.std()))

# %%
pd.DataFrame(rows, columns = [
    "interval", "end_to_end", "end to mean", "mean to mean", "mean to prev mean", "mean to end"
])
# Out:
#    interval  end_to_end  end to mean  mean to mean  mean to prev mean  \
# 0      1Min    0.000632     0.000653      0.000553           0.000813
# 1      2Min    0.000842     0.000889      0.000754           0.001113
# 2      3Min    0.001027     0.001115      0.000872           0.001320
# 3      4Min    0.001163     0.001258      0.000994           0.001508
# 4      5Min    0.001312     0.001403      0.001117           0.001685
# 5      6Min    0.001412     0.001515      0.001225           0.001845
# 6      7Min    0.001523     0.001634      0.001328           0.001993
# 7      8Min    0.001619     0.001738      0.001406           0.002123
# 8      9Min    0.001708     0.001831      0.001481           0.002241
# 9     10Min    0.001803     0.001931      0.001590           0.002389
# 10    15Min    0.002198     0.002355      0.001960           0.002921
# 11    30Min    0.003097     0.003299      0.002777           0.004142
# 12    60Min    0.004356     0.004649      0.003839           0.005718
# 13   120Min    0.006029     0.006358      0.005313           0.007936
# 14   180Min    0.006252     0.006558      0.005570           0.008353
# 15   240Min    0.007854     0.008387      0.007248           0.010845
# 16       1D    0.012914     0.013554      0.011700           0.017802
# 17       2D    0.016131     0.017689      0.014470           0.022538
# 18       1W    0.030696     0.036558      0.024981           0.039890
# 19       2W    0.038304     0.046842      0.035825           0.054845
# 20       1M    0.064925     0.068857      0.051602           0.067335
# 21       2M    0.103959     0.076894      0.053693           0.070610
# 22       3M    0.102349     0.088473      0.067846           0.034848
# 23       6M    0.081347     0.022896      0.042427                NaN
#
#     mean to end
# 0      0.000217
# 1      0.000335
# 2      0.000492
# 3      0.000522
# 4      0.000570
# 5      0.000608
# 6      0.000658
# 7      0.000683
# 8      0.000727
# 9      0.000743
# 10     0.000885
# 11     0.001228
# 12     0.001668
# 13     0.002311
# 14     0.002267
# 15     0.002862
# 16     0.003518
# 17     0.006585
# 18     0.017313
# 19     0.026559
# 20     0.022229
# 21     0.048815
# 22     0.033988
# 23     0.057608

# %% [markdown]
# ## Predicting 60 min ahead using 10, 15, 20 and 30 minutes windows

# %%
def resample_single_stock(single_stock, interval):
    return pd.DataFrame({
        'MaxPrice': single_stock['MaxPrice'].resample(interval).max(),
        'MinPrice': single_stock['MinPrice'].resample(interval).min(),
        'LastEndPrice': single_stock['EndPrice'].resample(interval).last(),
        'FirstStartPrice': single_stock['StartPrice'].resample(interval).first(),         
        'MeanEndPrice': single_stock['EndPrice'].resample(interval).mean(),        
        'HasTrade': single_stock['HasTrade'].resample(interval).max(),
    })

def prepare_single_stock_multi_intervals(mnemonic, predicted_price, main_interval, intervals):
    single_stock = df[df.Mnemonic == mnemonic].copy()
        
    main = resample_single_stock(single_stock, main_interval)
    # we use the same anchor
    anchor = main['MeanEndPrice']
    future_mean_price = main[predicted_price].shift(-1)
    main['AdjustedPctChange[t + 1]'] = (future_mean_price - anchor)/anchor
    
    all_intervals = [main_interval] + intervals
    
    for interval in all_intervals:
        sub = resample_single_stock(single_stock, interval)
        resampled = sub.resample(main_interval).last() 

        main['Direction@' + interval] = \
            2.0*(resampled['LastEndPrice'] - resampled['FirstStartPrice'])/ \
            anchor

        main['H1@' + interval] = - closer_to_with_normalization(
                                                 resampled['LastEndPrice'], 
                                                 resampled['MaxPrice'], 
                                                 resampled['MinPrice'],
                                                 anchor)    
        
        main['EndToMean@' + interval] = (resampled['LastEndPrice'] - resampled['MeanEndPrice'])/anchor
        
    main = main[main['HasTrade'] == 1.0]
    main = main.drop(columns = [
        'MaxPrice',
        'MinPrice',
        'LastEndPrice',
        'FirstStartPrice',         
        'MeanEndPrice',     
        'HasTrade'       
    ])
    return main

# %%
main_interval = '60Min'
intervals = ['2Min', '5Min', '10Min', '15Min', '20Min', '30Min']

single_stock = prepare_single_stock_multi_intervals('SIE', 'MeanEndPrice', main_interval, intervals)

k = 'AdjustedPctChange[t + 1]'
single_stock.corr()[[k]].sort_values(k, ascending=False)
# Out:
#                           AdjustedPctChange[t + 1]
# AdjustedPctChange[t + 1]                  1.000000
# EndToMean@60Min                           0.694290
# Direction@30Min                           0.633703
# H1@60Min                                  0.614180
# H1@30Min                                  0.588048
# EndToMean@30Min                           0.582287
# Direction@20Min                           0.551924
# Direction@60Min                           0.519582
# Direction@15Min                           0.493588
# EndToMean@20Min                           0.486650
# H1@20Min                                  0.473604
# EndToMean@15Min                           0.413438
# H1@15Min                                  0.400779
# Direction@10Min                           0.392419
# EndToMean@10Min                           0.323514
# H1@10Min                                  0.309173
# Direction@5Min                            0.247695
# EndToMean@5Min                            0.231562
# H1@5Min                                   0.210880
# Direction@2Min                            0.192312
# H1@2Min                                   0.147793
# EndToMean@2Min                            0.124329

# %%
main_interval = '60Min'
intervals = ['2Min', '5Min', '10Min', '15Min', '20Min', '30Min']

single_stock = prepare_single_stock_multi_intervals('SIE', 'LastEndPrice', main_interval, intervals)

k = 'AdjustedPctChange[t + 1]'
single_stock.corr()[[k]].sort_values(k, ascending=False)
# Out:
#                           AdjustedPctChange[t + 1]
# AdjustedPctChange[t + 1]                  1.000000
# EndToMean@60Min                           0.504806
# Direction@30Min                           0.468883
# H1@60Min                                  0.449401
# EndToMean@30Min                           0.430578
# H1@30Min                                  0.429825
# Direction@20Min                           0.410920
# Direction@60Min                           0.388155
# Direction@15Min                           0.359810
# EndToMean@20Min                           0.355766
# H1@20Min                                  0.345523
# EndToMean@15Min                           0.298978
# H1@15Min                                  0.287264
# Direction@10Min                           0.285013
# EndToMean@10Min                           0.232282
# H1@10Min                                  0.218876
# Direction@5Min                            0.173569
# EndToMean@5Min                            0.162471
# H1@5Min                                   0.150226
# Direction@2Min                            0.138976
# H1@2Min                                   0.098520
# EndToMean@2Min                            0.078964

# %%
# !echo "Last run on `date`"
# Out:
# Last run on Wed Jan 22 18:30:31 UTC 2020
