# %% [markdown]
# # Supporting Notebook 2: (Predictable and unpredicable prices)
#
# ## Modeling: What to Predict
# It is not straightforward to choose how to model stock behavior.
#
# Do we predict prices at 1 minute ahead, 10 minutes, or daily.
#
# Or should we predict all?
#
# What kind of price do we want to predict within an interval:
#
# - EndPrice
# - Mean(EndPrice)
# - WeightedMean(EndPrice)
# - MedianPrice
# - or the complete distribution of prices
# - if the complete distribution is to be predicted, do we predict the mean, variance and the skew. Do we discretize the distribution or we treat the available prices as samples from the distribution that we predict
#
# Another decision is whether to predict:
# - Percent of Change of Price
# - The sign of the price movement
# - The log of the actual price
#
# From a practical perspective, even in the presence of perfect predictions of prices in the future, one may not be able to make any money. This depends on
# - fees (the fee to enter and exit a position) should be lower than the expected change in the price
# - on seeing a quoted price how much above (when buying) and how far below (when selling) will one execute
# - volumes in the market. If one trades with very large volumes one will disrupt the supply and demand mechanism, therefore one will not execute at the desired price.
# - how the broker executes trades matters

# %% [markdown]
# # Insights: what is predictable
#
# In the current notebook we try to get an understanding what is easier and what is difficult to predict.
# For example, we find out that when we organize the data into intervals of say 10, 15, or 30 minutes,
# the mean price (`Mean(EndPrice)`) is much easier to predict than the end price `EndPrice`.
#
# We also find that when normalizing for `PctChange:X` of a feature `X`, we should use features that are normalized in the same way. One way to normalize the features is to divide them by `X[t - 1]`.
#
# One way to avoid this difficulty would be the following:
# - generate different linear combination of prices (averages are also linear combinations, and so are absolute returns)
# - compute the logs of all types of prices (or averages) of prices
# - we may also attempt to predict linear combination of prices, by taking logs
# - notice that is essentially a non-linear model, because we apply logs on sums of raw input features
# - when using logs care must be taken to avoid numbers close to zero as well as negative numbers.
# - however, log returns are approximately equal to percent change, so logs can be avoided
#
# We explore different ways to normalize the prices. One way would be to choose a more stable price as an "anchor", and replace all prices as linear functions such as:
# ```
# AnchorPrice = mean(Price[t - k, t - 1])
# NormPrice:X[i] = (Price:X[i] - AnchorPrice)/AnchorPrice, for i = t, t - 1, ...
# ```
#
#
# Regarding the prediction of an `EndPrice` we hypothesis that one would do better by predicting:
# - predict two prices, one 10 minutes ahead, one 5 minutes ahead
# - find the differences between the predictions
#
#
# In the future we will also explore the possiblity to predict entire distribution of prices, instead of just a single end-price, or averaged prices.

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (5, 3) # use bigger graphs

# %% [markdown]
# As usual we first load the data we prepared in notebook 2

# %%
input_file = '/data/cooked_v3.pkl'
df = pd.read_pickle(input_file)
df['CalcDateTime'] = df.index

# %% [markdown]
# Next we prepare a dataset consting of a single stock and compute derivative features
# (percent change) of a number of price features.

# %%
price_features = ['MaxPrice', 'MinPrice', 'LastEndPrice', 'FirstStartPrice', 'MeanEndPrice', 'MedianEndPrice', 
                  'MeanStartEndPrice', 'MeanMaxMinPrice', 'MeanAvg4Price',
                  'Direction1', 'Direction2', 'StdEndPrice', 'VolumeWeightedEndPrice']

log_ret_features = ['MaxPrice', 'MinPrice', 'LastEndPrice', 'FirstStartPrice', 'MeanEndPrice', 'MedianEndPrice', 
                  'MeanStartEndPrice', 'MeanMaxMinPrice', 'MeanAvg4Price']

indicator_features = [
    'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8',
    'G1', 'G2', 'G3', 'G4'
]

def pct_change_of(feature):
        return 'PctChange:' + feature
    
def log_return_f(feature):
    return 'LogReturn:' + feature

def adj_log_return_f(feature):
    return 'AdjLogReturn:' + feature

def rev_pct_change_of_at_t(feature, t):
        return 'RevPctChange[t - {}]:{}'.format(str(t), feature)
    
def shifted(feature):
    return feature + '[t - 1]'

def closer_to(pnt, a, b):
    return (np.absolute(pnt - a) - np.absolute(pnt - b))/pnt

def closer_to_with_normalization(pnt, a, b, norm):
    return (np.absolute(pnt - a) - np.absolute(pnt - b))/norm

def closer_to_or(pnt1, a, pnt2, b):
    return 2.0*(np.absolute(pnt1 - a) - np.absolute(pnt2 - b))/(pnt1 + pnt2)

def rev_pct_change(a, t):
    one_step_in_past = a.shift(1)
    t_steps_in_past = a.shift(1 + t)
    return (one_step_in_past - t_steps_in_past)/one_step_in_past
    
def log_return(a):
    return np.log(a) - np.log(a.shift(1))

def adj_log_return(a, norm):
    return np.log(a) - np.log(norm)

def norm_feature(feature_family, t, norm_feature):
    return "{}@WithNorm({})[t - {}]".format(feature_family, norm_feature, t)    
    
def weighted_mean(prices, volumes, interval):
    prices_times_volumes = prices * volumes
    num = prices_times_volumes.resample(interval).sum()
    denom = volumes.resample(interval).sum()
    return num/denom
    
# use this to experiment with custom weights    
def custom_linear_comb(prices):
    prices = prices.values[:,]
    prices = prices[~np.isnan(prices)]
    if prices.shape[0] == 0:
        return np.nan
    weights = np.zeros_like(prices)
    if prices.shape[0] < 3:
        return prices[-1]
    weights[-1] = 1.0
    weights[-2] = 0.5
    return np.sum(np.multiply(prices, weights))/np.sum(weights)    

def prepare_single_stock(mnemonic, interval):
    # TODO: add traded volume to averaging of prices, also traded volume weighted differently (e.g. exponential weighting)
    # TODO: one can weight max/min/start/end price differently depending on the move
    # TODO: add exponential weighting of the prices within a window (also there are different ways to center)
    single_stock = df[df.Mnemonic == mnemonic].copy()
    single_stock['StartEndPrice'] = 0.5*(single_stock['StartPrice'] + single_stock['EndPrice'])
    single_stock['MaxMinPrice'] = 0.5*(single_stock['MaxPrice'] + single_stock['MinPrice'])
    single_stock['Avg4Price'] = 0.25*(single_stock['MaxPrice'] + single_stock['MinPrice'] + 
                                      single_stock['StartPrice'] + single_stock['EndPrice'])
    
    # TODO: add smoothed traded volume
    single_stock['PctChange'] = single_stock['EndPrice'].pct_change()
    single_stock['SmoothedTradedVolume'] = single_stock['TradedVolume'].ewm(com=2.5).mean()
    
    single_stock['Direction'] = \
        2.0*(single_stock['EndPrice'] - single_stock['StartPrice'])/ \
        (single_stock['EndPrice'] + single_stock['StartPrice'])
        
    single_stock['F1'] = - closer_to(single_stock['EndPrice'], single_stock['MaxPrice'], single_stock['MinPrice'])
        

    resampled = pd.DataFrame({
        'MaxPrice': single_stock['MaxPrice'].resample(interval).max(),
        'MinPrice': single_stock['MinPrice'].resample(interval).min(),
        'MeanStartEndPrice': single_stock['StartEndPrice'].resample(interval).mean(),  
        'MeanMaxMinPrice': single_stock['MaxMinPrice'].resample(interval).mean(), 
        'MeanAvg4Price': single_stock['Avg4Price'].resample(interval).mean(),  
        'CustomLinearComb': single_stock['Avg4Price'].resample(interval).apply(custom_linear_comb),         
        'FirstStartPrice': single_stock['StartPrice'].resample(interval).first(),        
        'LastEndPrice': single_stock['EndPrice'].resample(interval).last(), 
        'MeanEndPrice': single_stock['EndPrice'].resample(interval).mean(), 
        'MedianEndPrice': single_stock['EndPrice'].resample(interval).median(),
        'VolumeWeightedEndPrice': weighted_mean(single_stock['EndPrice'], single_stock['SmoothedTradedVolume'], interval),
        'VolumeWeightedPctChange': weighted_mean(single_stock['PctChange'], single_stock['SmoothedTradedVolume'], interval),
        
        'StdEndPrice': single_stock['EndPrice'].resample(interval).std(),
        'HasTrade': single_stock['HasTrade'].resample(interval).max(),
        'G1': single_stock['Direction'].resample(interval).mean(),
        'G2': np.sign(single_stock['Direction']).resample(interval).mean(),
        'G3': single_stock['F1'].resample(interval).mean(),
        'G4': np.sign(single_stock['F1']).resample(interval).mean()        
    })
    resampled['AdjustedPctChange'] = (resampled['LastEndPrice'] - resampled['MeanEndPrice'])/resampled['MeanEndPrice']
    resampled['AdjustedPctChange[t - 1]'] = resampled['AdjustedPctChange'].shift(1)
    
    resampled['MeanPctChangeV2'] = (resampled['MeanEndPrice'] - resampled['LastEndPrice'].shift(1))/resampled['LastEndPrice'].shift(1)
    
    anchor = resampled['MeanEndPrice'].shift(1)
    resampled[adj_log_return_f('LastEndPrice')] = adj_log_return(resampled['LastEndPrice'], anchor)
    resampled[shifted(adj_log_return_f('LastEndPrice'))] = \
        adj_log_return(resampled['LastEndPrice'].shift(1), anchor)
    
    resampled['Direction1'] = \
        2.0*(resampled['LastEndPrice'] - resampled['FirstStartPrice'])/ \
        (resampled['LastEndPrice'] + resampled['FirstStartPrice'])
    
    resampled['Direction2'] = \
        2.0*(resampled['LastEndPrice'] - resampled['FirstStartPrice'])/ \
        resampled['MeanEndPrice'].shift(1)
        
    resampled[shifted('Direction1')] = resampled['Direction1'].shift(1)
    resampled[shifted('Direction2')] = resampled['Direction2'].shift(1)
    
    for f in ['MinPrice', 'MaxPrice', 'LastEndPrice', 'FirstStartPrice']:
        resampled[shifted(f)] = resampled[f].shift(1)
        
    resampled['F1'] = - closer_to(resampled['LastEndPrice'], resampled['MaxPrice'], resampled['MinPrice'])
    resampled['F2'] = - closer_to(resampled['MaxPrice'], resampled['LastEndPrice'], resampled['FirstStartPrice'])
    resampled['F3'] = closer_to(resampled['MinPrice'], resampled['LastEndPrice'], resampled['FirstStartPrice'])
    resampled['F4'] = - closer_to(resampled['LastEndPrice'], resampled['MaxPrice'], resampled[shifted('MaxPrice')])
    resampled['F5'] = closer_to(resampled['LastEndPrice'], resampled['MinPrice'], resampled[shifted('MinPrice')])
    
    resampled['F6'] = - closer_to_or(resampled['LastEndPrice'], resampled['MaxPrice'],
                                   resampled[shifted('LastEndPrice')], resampled[shifted('MaxPrice')])

    resampled['F7'] = closer_to_or(resampled['LastEndPrice'], resampled['MinPrice'],
                                   resampled[shifted('LastEndPrice')], resampled[shifted('MinPrice')])
    
    
    resampled['F8'] = np.where(resampled['Direction2'] >= 0, resampled['F4'] , resampled['F5'])
    
    
    for t in range(1, 5):    
        # note: normalization is fixed
        resampled[norm_feature('H1', t, 'MeanEndPrice')] = - closer_to_with_normalization(
                                             resampled['LastEndPrice'].shift(t), 
                                             resampled['MaxPrice'].shift(t), 
                                             resampled['MinPrice'].shift(t),
                                             resampled['MeanEndPrice'].shift(1))    
        
    
    for f in indicator_features:
        resampled[shifted(f)] = resampled[f].shift(1)
        
    for f in price_features:
        pct_change_f = pct_change_of(f)
        resampled[pct_change_f] = resampled[f].pct_change()
        resampled[shifted(pct_change_f)] = resampled[pct_change_f].shift(1) 
    
    for f in price_features:
        for t in range(1, 5):
            rev_pct_change_f_t = rev_pct_change_of_at_t(f, t)
            resampled[rev_pct_change_f_t] = rev_pct_change(resampled[f], t)    
        

    for f in log_ret_features:
        log_ret_f = log_return_f(f)
        resampled[log_ret_f] = log_return(resampled[f])
        resampled[shifted(log_ret_f)] = resampled[log_ret_f].shift(1) 
        
    resampled = resampled[resampled['HasTrade'] == 1.0]
    
    return resampled

def correlation_with_feature(single_stock, corr_feature):
    pct_change_of_f = corr_feature
    sh_dir1 = shifted('Direction1')
    sh_dir2 = shifted('Direction2')    
    d = {
        pct_change_of_f: single_stock[pct_change_of_f],
        sh_dir1: single_stock[sh_dir1],
        sh_dir2: single_stock[sh_dir2]        
    }
    
    for f in indicator_features:
        d[shifted(f)] = single_stock[shifted(f)]
        
    d['AdjustedPctChange[t - 1]'] = single_stock['AdjustedPctChange[t - 1]']    
    d[adj_log_return_f('LastEndPrice')] = single_stock[adj_log_return_f('LastEndPrice')]
    d[shifted(adj_log_return_f('LastEndPrice'))] = single_stock[shifted(adj_log_return_f('LastEndPrice'))]
    
    d['MeanPctChangeV2'] = single_stock['MeanPctChangeV2']
    
    for f in price_features:
        pct_change_shifted = shifted(pct_change_of(f))
        d[pct_change_shifted] = single_stock[pct_change_shifted]
        
    for t in range(1, 5):    
        # note: normalization is fixed
        f = norm_feature('H1', t, 'MeanEndPrice')
        d[f] = single_stock[f]
            
    for f in log_ret_features:
        log_ret_f = log_return_f(f)
        d[log_ret_f] = single_stock[log_ret_f]
            
    for f in price_features:
        for t in range(1, 5):
            rev_pct_change_f_t = rev_pct_change_of_at_t(f, t)
            d[rev_pct_change_f_t] = single_stock[rev_pct_change_f_t]
            
    d[shifted('VolumeWeightedPctChange')] = single_stock[('VolumeWeightedPctChange')].shift(1)
    corr = pd.DataFrame(d).corr()
    row_id = np.argwhere(corr.index.values == pct_change_of_f)[0][0]
    return corr.iloc[[row_id]].drop(columns=[pct_change_of_f])

def corr_pct_change(single_stock, feature):
    pct_change_of_f = pct_change_of(feature)
    return correlation_with_feature(single_stock, pct_change_of_f)

def corr_log_return(single_stock, feature):
    return correlation_with_feature(single_stock, log_return_f(feature))

def find_most_correlated_features(single_stock, feature):
    corrs = correlation_with_feature(single_stock, feature).T
    corrs['AbsCorr'] = np.absolute(corrs[feature])
    sorted_corrs = corrs.sort_values('AbsCorr', ascending=False)
    selected_names = filter(lambda n: n.find('[t - 1') >= 0 or n.find('[t - 2') >= 0, list(sorted_corrs.index.values))
    sorted_corrs = sorted_corrs.T[selected_names].T
    return sorted_corrs

# %% [markdown]
# We choose a single stock, for example 'SIE' (Siemens)

# %%
single_stock = prepare_single_stock('SIE', '30Min')

# %% [markdown]
# We look at the corrlations of all the other price features from previous time periods `(t - 1)`.
# We could also say that we investigate if a single feature from the previous time period `(t - 1)`
# would be predictive of the change in the next time period `(t)`

# %% [markdown]
# We first study the `LastEndPrice` or the last end price in the interval `t` (here interval is 30 minutes).
# As it can be seen there are no strong correlations.

# %%
corr_pct_change(single_stock, 'LastEndPrice')
# Out:
#                         AdjLogReturn:LastEndPrice  \
# PctChange:LastEndPrice                   0.875334
#
#                         AdjLogReturn:LastEndPrice[t - 1]  \
# PctChange:LastEndPrice                         -0.044889
#
#                         AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:LastEndPrice                  -0.04486          -0.011198
#
#                         Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# PctChange:LastEndPrice            -0.0297  -0.027385  -0.011297  -0.011028
#
#                         F4[t - 1]  F5[t - 1]               ...                \
# PctChange:LastEndPrice    0.02114  -0.027374               ...
#
#                         RevPctChange[t - 4]:MaxPrice  \
# PctChange:LastEndPrice                     -0.038945
#
#                         RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:LastEndPrice                          -0.021345
#
#                         RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:LastEndPrice                         -0.021353
#
#                         RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:LastEndPrice                            -0.021357
#
#                         RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:LastEndPrice                              -0.021333
#
#                         RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:LastEndPrice                           -0.015984
#
#                         RevPctChange[t - 4]:MinPrice  \
# PctChange:LastEndPrice                     -0.011112
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# PctChange:LastEndPrice                        -0.021343
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:LastEndPrice                                    -0.02265
#
#                         VolumeWeightedPctChange[t - 1]
# PctChange:LastEndPrice                       -0.014676
#
# [1 rows x 97 columns]

# %% [markdown]
# Next we look for correlations with the mean prices:
# - MeanAvg4Price: we averaged all 4 prices available within a minute and then averaged within an interval like 10Min
# - MeanMaxMinPrice: took the average of Min and Max prices and then averaged within an interval
# - MeanStartEndPrice: took the average of Start and End prices and then averaged within an interval
#
# # Conclusion:
#
# - The more averaging was done, the easier to predict
# - EndPrice is very difficult to predict, but the mean price is not
# - The median of the end price is harder to predict than the mean, but a lot easier than the end price

# %%
corr_pct_change(single_stock, 'MeanAvg4Price')
# Out:
#                          AdjLogReturn:LastEndPrice  \
# PctChange:MeanAvg4Price                   0.886189
#
#                          AdjLogReturn:LastEndPrice[t - 1]  \
# PctChange:MeanAvg4Price                          0.649081
#
#                          AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:MeanAvg4Price                  0.649087           0.499324
#
#                          Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# PctChange:MeanAvg4Price           0.546771   0.592774   0.500389   0.497669
#
#                          F4[t - 1]  F5[t - 1]               ...                \
# PctChange:MeanAvg4Price   0.091224   0.101009               ...
#
#                          RevPctChange[t - 4]:MaxPrice  \
# PctChange:MeanAvg4Price                      0.071413
#
#                          RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:MeanAvg4Price                           0.069717
#
#                          RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:MeanAvg4Price                           0.07359
#
#                          RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:MeanAvg4Price                             0.069911
#
#                          RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:MeanAvg4Price                               0.069521
#
#                          RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:MeanAvg4Price                            0.068348
#
#                          RevPctChange[t - 4]:MinPrice  \
# PctChange:MeanAvg4Price                      0.091924
#
#                          RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanAvg4Price                        -0.029574
#
#                          RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanAvg4Price                                    0.088645
#
#                          VolumeWeightedPctChange[t - 1]
# PctChange:MeanAvg4Price                        0.276965
#
# [1 rows x 97 columns]

# %%
find_most_correlated_features(single_stock, pct_change_of('MeanAvg4Price'))
# Out:
#                                             PctChange:MeanAvg4Price   AbsCorr
# AdjustedPctChange[t - 1]                                   0.649087  0.649087
# F1[t - 1]                                                  0.592774  0.592774
# H1@WithNorm(MeanEndPrice)[t - 1]                           0.592662  0.592662
# RevPctChange[t - 1]:LastEndPrice                           0.546920  0.546920
# Direction2[t - 1]                                          0.546771  0.546771
# F2[t - 1]                                                  0.500389  0.500389
# Direction1[t - 1]                                          0.499324  0.499324
# F3[t - 1]                                                  0.497669  0.497669
# PctChange:LastEndPrice[t - 1]                              0.432989  0.432989
# G1[t - 1]                                                  0.427626  0.427626
# F8[t - 1]                                                  0.394078  0.394078
# RevPctChange[t - 2]:LastEndPrice                           0.382852  0.382852
# F6[t - 1]                                                  0.357508  0.357508
# G3[t - 1]                                                  0.344700  0.344700
# G2[t - 1]                                                  0.338498  0.338498
# F7[t - 1]                                                  0.331484  0.331484
# VolumeWeightedPctChange[t - 1]                             0.276965  0.276965
# RevPctChange[t - 1]:VolumeWeightedEndPrice                 0.276407  0.276407
# G4[t - 1]                                                  0.257448  0.257448
# RevPctChange[t - 1]:MeanEndPrice                           0.248658  0.248658
# RevPctChange[t - 1]:MeanMaxMinPrice                        0.239763  0.239763
# RevPctChange[t - 1]:MeanAvg4Price                          0.239549  0.239549
# RevPctChange[t - 1]:MeanStartEndPrice                      0.239318  0.239318
# RevPctChange[t - 1]:MedianEndPrice                         0.227061  0.227061
# PctChange:VolumeWeightedEndPrice[t - 1]                    0.225874  0.225874
# RevPctChange[t - 1]:MinPrice                               0.216941  0.216941
# RevPctChange[t - 1]:MaxPrice                               0.216291  0.216291
# PctChange:MeanEndPrice[t - 1]                              0.207253  0.207253
# PctChange:MeanMaxMinPrice[t - 1]                           0.199342  0.199342
# PctChange:MeanAvg4Price[t - 1]                             0.199224  0.199224
# PctChange:MeanStartEndPrice[t - 1]                         0.199085  0.199085
# PctChange:MedianEndPrice[t - 1]                            0.195619  0.195619
# PctChange:MaxPrice[t - 1]                                  0.194324  0.194324
# PctChange:MinPrice[t - 1]                                  0.179500  0.179500
# RevPctChange[t - 2]:VolumeWeightedEndPrice                 0.174527  0.174527
# RevPctChange[t - 2]:MinPrice                               0.170577  0.170577
# RevPctChange[t - 2]:MeanEndPrice                           0.153162  0.153162
# RevPctChange[t - 2]:MeanMaxMinPrice                        0.147913  0.147913
# RevPctChange[t - 2]:MeanAvg4Price                          0.147482  0.147482
# RevPctChange[t - 2]:MeanStartEndPrice                      0.147047  0.147047
# RevPctChange[t - 2]:MedianEndPrice                         0.147020  0.147020
# RevPctChange[t - 2]:MaxPrice                               0.124831  0.124831
# F5[t - 1]                                                  0.101009  0.101009
# F4[t - 1]                                                  0.091224  0.091224
# RevPctChange[t - 2]:StdEndPrice                           -0.043346  0.043346
# RevPctChange[t - 1]:FirstStartPrice                       -0.024391  0.024391
# PctChange:Direction1[t - 1]                               -0.021702  0.021702
# RevPctChange[t - 1]:Direction2                            -0.019967  0.019967
# H1@WithNorm(MeanEndPrice)[t - 2]                          -0.016854  0.016854
# PctChange:Direction2[t - 1]                               -0.014511  0.014511
# RevPctChange[t - 2]:FirstStartPrice                       -0.014214  0.014214
# PctChange:StdEndPrice[t - 1]                               0.010469  0.010469
# RevPctChange[t - 1]:Direction1                            -0.007086  0.007086
# PctChange:FirstStartPrice[t - 1]                           0.005321  0.005321
# RevPctChange[t - 2]:Direction1                             0.003093  0.003093
# RevPctChange[t - 2]:Direction2                             0.002525  0.002525
# RevPctChange[t - 1]:StdEndPrice                           -0.002335  0.002335

# %%
corr_pct_change(single_stock, 'MeanMaxMinPrice')
# Out:
#                            AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:MeanMaxMinPrice                  0.648601           0.498502
#
#                            Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# PctChange:MeanMaxMinPrice           0.546014   0.592666   0.499563   0.496845
#
#                            F4[t - 1]  F5[t - 1]  F6[t - 1]  F7[t - 1]  \
# PctChange:MeanMaxMinPrice     0.0917   0.101526   0.357278   0.331763
#
#                                         ...                \
# PctChange:MeanMaxMinPrice               ...
#
#                            RevPctChange[t - 4]:MaxPrice  \
# PctChange:MeanMaxMinPrice                      0.071013
#
#                            RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:MeanMaxMinPrice                           0.069293
#
#                            RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:MeanMaxMinPrice                          0.073177
#
#                            RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:MeanMaxMinPrice                             0.069474
#
#                            RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:MeanMaxMinPrice                               0.069111
#
#                            RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:MeanMaxMinPrice                            0.067948
#
#                            RevPctChange[t - 4]:MinPrice  \
# PctChange:MeanMaxMinPrice                      0.091528
#
#                            RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanMaxMinPrice                        -0.029617
#
#                            RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanMaxMinPrice                                    0.088248
#
#                            VolumeWeightedPctChange[t - 1]
# PctChange:MeanMaxMinPrice                        0.276102
#
# [1 rows x 94 columns]

# %%
corr_pct_change(single_stock, 'MeanStartEndPrice')
# Out:
#                              AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:MeanStartEndPrice                  0.649527           0.500111
#
#                              Direction2[t - 1]  F1[t - 1]  F2[t - 1]  \
# PctChange:MeanStartEndPrice            0.54749   0.592839   0.501179
#
#                              F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  \
# PctChange:MeanStartEndPrice   0.498458   0.090742   0.100484   0.357715
#
#                              F7[t - 1]               ...                \
# PctChange:MeanStartEndPrice   0.331181               ...
#
#                              RevPctChange[t - 4]:MaxPrice  \
# PctChange:MeanStartEndPrice                      0.071808
#
#                              RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:MeanStartEndPrice                           0.070136
#
#                              RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:MeanStartEndPrice                          0.073999
#
#                              RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:MeanStartEndPrice                             0.070345
#
#                              RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:MeanStartEndPrice                               0.069926
#
#                              RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:MeanStartEndPrice                            0.068744
#
#                              RevPctChange[t - 4]:MinPrice  \
# PctChange:MeanStartEndPrice                      0.092315
#
#                              RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanStartEndPrice                        -0.029529
#
#                              RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanStartEndPrice                                    0.089035
#
#                              VolumeWeightedPctChange[t - 1]
# PctChange:MeanStartEndPrice                        0.277798
#
# [1 rows x 94 columns]

# %%
corr_pct_change(single_stock, 'MeanEndPrice')
# Out:
#                         AdjLogReturn:LastEndPrice  \
# PctChange:MeanEndPrice                   0.893023
#
#                         AdjLogReturn:LastEndPrice[t - 1]  \
# PctChange:MeanEndPrice                          0.633271
#
#                         AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:MeanEndPrice                  0.633278           0.484106
#
#                         Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# PctChange:MeanEndPrice           0.528506    0.57733   0.485131   0.482517
#
#                         F4[t - 1]  F5[t - 1]               ...                \
# PctChange:MeanEndPrice   0.091301   0.099043               ...
#
#                         RevPctChange[t - 4]:MaxPrice  \
# PctChange:MeanEndPrice                      0.066974
#
#                         RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:MeanEndPrice                           0.065182
#
#                         RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:MeanEndPrice                          0.068844
#
#                         RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:MeanEndPrice                             0.065384
#
#                         RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:MeanEndPrice                                0.06498
#
#                         RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:MeanEndPrice                            0.063751
#
#                         RevPctChange[t - 4]:MinPrice  \
# PctChange:MeanEndPrice                      0.087711
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MeanEndPrice                        -0.029297
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice                                    0.083367
#
#                         VolumeWeightedPctChange[t - 1]
# PctChange:MeanEndPrice                        0.264644
#
# [1 rows x 97 columns]

# %%
corr_pct_change(single_stock, 'MedianEndPrice')
# Out:
#                           AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:MedianEndPrice                  0.619535           0.433678
#
#                           Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# PctChange:MedianEndPrice           0.498296    0.53076   0.434843   0.431914
#
#                           F4[t - 1]  F5[t - 1]  F6[t - 1]  F7[t - 1]  \
# PctChange:MedianEndPrice   0.094451   0.102715   0.336348    0.30959
#
#                                        ...                \
# PctChange:MedianEndPrice               ...
#
#                           RevPctChange[t - 4]:MaxPrice  \
# PctChange:MedianEndPrice                      0.061692
#
#                           RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:MedianEndPrice                           0.054922
#
#                           RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:MedianEndPrice                          0.058357
#
#                           RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:MedianEndPrice                             0.055128
#
#                           RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:MedianEndPrice                               0.054715
#
#                           RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:MedianEndPrice                            0.045778
#
#                           RevPctChange[t - 4]:MinPrice  \
# PctChange:MedianEndPrice                      0.082627
#
#                           RevPctChange[t - 4]:StdEndPrice  \
# PctChange:MedianEndPrice                         -0.02849
#
#                           RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:MedianEndPrice                                    0.073163
#
#                           VolumeWeightedPctChange[t - 1]
# PctChange:MedianEndPrice                         0.24804
#
# [1 rows x 94 columns]

# %%
corr_pct_change(single_stock, 'VolumeWeightedEndPrice')
# Out:
#                                   AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# PctChange:VolumeWeightedEndPrice                   0.57062           0.405897
#
#                                   Direction2[t - 1]  F1[t - 1]  F2[t - 1]  \
# PctChange:VolumeWeightedEndPrice           0.466458   0.515441   0.407015
#
#                                   F3[t - 1]  F4[t - 1]  F5[t - 1]  F6[t - 1]  \
# PctChange:VolumeWeightedEndPrice   0.404191   0.094179   0.092344   0.320096
#
#                                   F7[t - 1]               ...                \
# PctChange:VolumeWeightedEndPrice   0.307567               ...
#
#                                   RevPctChange[t - 4]:MaxPrice  \
# PctChange:VolumeWeightedEndPrice                       0.04479
#
#                                   RevPctChange[t - 4]:MeanAvg4Price  \
# PctChange:VolumeWeightedEndPrice                           0.042424
#
#                                   RevPctChange[t - 4]:MeanEndPrice  \
# PctChange:VolumeWeightedEndPrice                          0.045507
#
#                                   RevPctChange[t - 4]:MeanMaxMinPrice  \
# PctChange:VolumeWeightedEndPrice                             0.042602
#
#                                   RevPctChange[t - 4]:MeanStartEndPrice  \
# PctChange:VolumeWeightedEndPrice                               0.042246
#
#                                   RevPctChange[t - 4]:MedianEndPrice  \
# PctChange:VolumeWeightedEndPrice                            0.042875
#
#                                   RevPctChange[t - 4]:MinPrice  \
# PctChange:VolumeWeightedEndPrice                      0.057806
#
#                                   RevPctChange[t - 4]:StdEndPrice  \
# PctChange:VolumeWeightedEndPrice                        -0.021437
#
#                                   RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# PctChange:VolumeWeightedEndPrice                                    0.052565
#
#                                   VolumeWeightedPctChange[t - 1]
# PctChange:VolumeWeightedEndPrice                         0.21799
#
# [1 rows x 94 columns]

# %%
correlation_with_feature(single_stock, 'MeanPctChangeV2')
# Out:
#                  AdjLogReturn:LastEndPrice  AdjLogReturn:LastEndPrice[t - 1]  \
# MeanPctChangeV2                   0.766463                          -0.05235
#
#                  AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# MeanPctChangeV2                 -0.052341          -0.024095
#
#                  Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# MeanPctChangeV2          -0.038681  -0.036089  -0.024238   -0.02394
#
#                  F4[t - 1]  F5[t - 1]               ...                \
# MeanPctChangeV2   0.024079  -0.023621               ...
#
#                  RevPctChange[t - 4]:MaxPrice  \
# MeanPctChangeV2                     -0.041307
#
#                  RevPctChange[t - 4]:MeanAvg4Price  \
# MeanPctChangeV2                          -0.024616
#
#                  RevPctChange[t - 4]:MeanEndPrice  \
# MeanPctChangeV2                         -0.025007
#
#                  RevPctChange[t - 4]:MeanMaxMinPrice  \
# MeanPctChangeV2                            -0.024613
#
#                  RevPctChange[t - 4]:MeanStartEndPrice  \
# MeanPctChangeV2                              -0.024618
#
#                  RevPctChange[t - 4]:MedianEndPrice  \
# MeanPctChangeV2                           -0.021375
#
#                  RevPctChange[t - 4]:MinPrice  \
# MeanPctChangeV2                     -0.011481
#
#                  RevPctChange[t - 4]:StdEndPrice  \
# MeanPctChangeV2                        -0.023722
#
#                  RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# MeanPctChangeV2                                   -0.026919
#
#                  VolumeWeightedPctChange[t - 1]
# MeanPctChangeV2                       -0.022443
#
# [1 rows x 96 columns]

# %%
find_most_correlated_features(single_stock, 'MeanPctChangeV2')
# Out:
#                                             MeanPctChangeV2   AbsCorr
# G4[t - 1]                                         -0.060184  0.060184
# G2[t - 1]                                         -0.056568  0.056568
# G3[t - 1]                                         -0.052721  0.052721
# AdjLogReturn:LastEndPrice[t - 1]                  -0.052350  0.052350
# AdjustedPctChange[t - 1]                          -0.052341  0.052341
# G1[t - 1]                                         -0.044197  0.044197
# RevPctChange[t - 2]:StdEndPrice                   -0.040138  0.040138
# Direction2[t - 1]                                 -0.038681  0.038681
# PctChange:StdEndPrice[t - 1]                       0.038139  0.038139
# RevPctChange[t - 1]:LastEndPrice                  -0.036484  0.036484
# F1[t - 1]                                         -0.036089  0.036089
# H1@WithNorm(MeanEndPrice)[t - 1]                  -0.036025  0.036025
# RevPctChange[t - 2]:MaxPrice                      -0.033706  0.033706
# PctChange:Direction2[t - 1]                        0.032840  0.032840
# RevPctChange[t - 2]:LastEndPrice                  -0.031848  0.031848
# PctChange:Direction1[t - 1]                        0.031473  0.031473
# PctChange:MedianEndPrice[t - 1]                    0.031334  0.031334
# RevPctChange[t - 1]:FirstStartPrice               -0.029440  0.029440
# PctChange:MeanEndPrice[t - 1]                      0.027104  0.027104
# PctChange:MeanMaxMinPrice[t - 1]                   0.026176  0.026176
# PctChange:MeanAvg4Price[t - 1]                     0.026131  0.026131
# PctChange:MeanStartEndPrice[t - 1]                 0.026083  0.026083
# PctChange:VolumeWeightedEndPrice[t - 1]            0.025807  0.025807
# F2[t - 1]                                         -0.024238  0.024238
# Direction1[t - 1]                                 -0.024095  0.024095
# F4[t - 1]                                          0.024079  0.024079
# F3[t - 1]                                         -0.023940  0.023940
# F5[t - 1]                                         -0.023621  0.023621
# F7[t - 1]                                         -0.023280  0.023280
# VolumeWeightedPctChange[t - 1]                    -0.022443  0.022443
# RevPctChange[t - 2]:VolumeWeightedEndPrice        -0.020401  0.020401
# F6[t - 1]                                         -0.020263  0.020263
# RevPctChange[t - 1]:StdEndPrice                    0.019409  0.019409
# F8[t - 1]                                         -0.019232  0.019232
# RevPctChange[t - 1]:MaxPrice                      -0.018022  0.018022
# RevPctChange[t - 2]:MeanEndPrice                  -0.017594  0.017594
# RevPctChange[t - 2]:MeanStartEndPrice             -0.017385  0.017385
# RevPctChange[t - 2]:MeanAvg4Price                 -0.017261  0.017261
# RevPctChange[t - 1]:Direction1                    -0.017235  0.017235
# RevPctChange[t - 2]:MeanMaxMinPrice               -0.017136  0.017136
# PctChange:MaxPrice[t - 1]                          0.016031  0.016031
# RevPctChange[t - 1]:Direction2                    -0.015711  0.015711
# RevPctChange[t - 2]:MedianEndPrice                -0.013401  0.013401
# RevPctChange[t - 1]:MinPrice                      -0.013273  0.013273
# RevPctChange[t - 1]:MedianEndPrice                 0.010392  0.010392
# RevPctChange[t - 2]:Direction2                     0.007996  0.007996
# H1@WithNorm(MeanEndPrice)[t - 2]                  -0.007786  0.007786
# RevPctChange[t - 2]:Direction1                     0.006896  0.006896
# PctChange:MinPrice[t - 1]                          0.006794  0.006794
# PctChange:FirstStartPrice[t - 1]                  -0.006349  0.006349
# RevPctChange[t - 2]:FirstStartPrice               -0.002478  0.002478
# RevPctChange[t - 1]:MeanStartEndPrice              0.002234  0.002234
# RevPctChange[t - 1]:MeanAvg4Price                  0.002215  0.002215
# RevPctChange[t - 1]:MeanMaxMinPrice                0.002197  0.002197
# RevPctChange[t - 1]:MeanEndPrice                   0.001668  0.001668
# RevPctChange[t - 1]:VolumeWeightedEndPrice        -0.001052  0.001052
# PctChange:LastEndPrice[t - 1]                      0.000171  0.000171
# RevPctChange[t - 2]:MinPrice                       0.000006  0.000006

# %% [markdown]
# Let us settle for the moment on the 'MeanEndPrice', and compute the correlations over multiple intervals

# %%
# some of the better features
x_features = [
    'AdjustedPctChange[t - 1]',
    'F1[t - 1]',
    'H1@WithNorm(MeanEndPrice)[t - 1]',
    'RevPctChange[t - 1]:LastEndPrice',
    'F2[t - 1]',
    'Direction2[t - 1]',
    'F3[t - 1]',
    'G1[t - 1]',
    'G3[t - 1]',
    'PctChange:LastEndPrice[t - 1]',
    'RevPctChange[t - 2]:LastEndPrice',
    'F6[t - 1]',
    'G2[t - 1]',
    'F7[t - 1]',
    'G4[t - 1]',
    'RevPctChange[t - 1]:VolumeWeightedEndPrice',
    'RevPctChange[t - 1]:MinPrice',
    'RevPctChange[t - 1]:MeanEndPrice',
    'RevPctChange[t - 1]:MeanMaxMinPrice',
    'RevPctChange[t - 1]:MeanAvg4Price',
    'RevPctChange[t - 1]:MeanStartEndPrice',
    'RevPctChange[t - 1]:MaxPrice']

# %%
intervals = ['1Min', '2Min', '3Min', '4Min', '5Min', '6Min', '7Min', '8Min', '9Min', '10Min', 
             '15Min', '30Min', '60Min', '120Min', '180Min', '240Min',
             '1D', '2D', '1W', '2W']
def corr_over_intervals(stock):
    results = []
    for interval in intervals:
        single_stock = prepare_single_stock(stock, interval)
        cr = corr_pct_change(single_stock, 'MeanEndPrice')
        cr.index = [cr.index[0] + "@" + interval]
        results.append(cr)
    return pd.concat(results)

# %%
corr_over_intervals('BMW')[x_features]
# Out:
#                                AdjustedPctChange[t - 1]  F1[t - 1]  \
# PctChange:MeanEndPrice@1Min                         NaN  -0.039041
# PctChange:MeanEndPrice@2Min                    0.341110   0.289113
# PctChange:MeanEndPrice@3Min                    0.555537   0.500738
# PctChange:MeanEndPrice@4Min                    0.569054   0.528768
# PctChange:MeanEndPrice@5Min                    0.564955   0.532253
# PctChange:MeanEndPrice@6Min                    0.589749   0.555853
# PctChange:MeanEndPrice@7Min                    0.626719   0.593687
# PctChange:MeanEndPrice@8Min                    0.629170   0.592355
# PctChange:MeanEndPrice@9Min                    0.620197   0.582707
# PctChange:MeanEndPrice@10Min                   0.613953   0.573533
# PctChange:MeanEndPrice@15Min                   0.657064   0.603944
# PctChange:MeanEndPrice@30Min                   0.663278   0.618686
# PctChange:MeanEndPrice@60Min                   0.700211   0.655081
# PctChange:MeanEndPrice@120Min                  0.705072   0.637291
# PctChange:MeanEndPrice@180Min                  0.692578   0.646827
# PctChange:MeanEndPrice@240Min                  0.734666   0.631630
# PctChange:MeanEndPrice@1D                      0.409717   0.379122
# PctChange:MeanEndPrice@2D                      0.570231   0.545273
# PctChange:MeanEndPrice@1W                      0.672440   0.641604
# PctChange:MeanEndPrice@2W                      0.673966   0.687500
#
#                                H1@WithNorm(MeanEndPrice)[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.039041
# PctChange:MeanEndPrice@2Min                            0.289109
# PctChange:MeanEndPrice@3Min                            0.500195
# PctChange:MeanEndPrice@4Min                            0.528799
# PctChange:MeanEndPrice@5Min                            0.532383
# PctChange:MeanEndPrice@6Min                            0.556019
# PctChange:MeanEndPrice@7Min                            0.593914
# PctChange:MeanEndPrice@8Min                            0.592385
# PctChange:MeanEndPrice@9Min                            0.582823
# PctChange:MeanEndPrice@10Min                           0.573560
# PctChange:MeanEndPrice@15Min                           0.603890
# PctChange:MeanEndPrice@30Min                           0.618696
# PctChange:MeanEndPrice@60Min                           0.655095
# PctChange:MeanEndPrice@120Min                          0.637620
# PctChange:MeanEndPrice@180Min                          0.646824
# PctChange:MeanEndPrice@240Min                          0.631795
# PctChange:MeanEndPrice@1D                              0.378796
# PctChange:MeanEndPrice@2D                              0.544029
# PctChange:MeanEndPrice@1W                              0.639837
# PctChange:MeanEndPrice@2W                              0.680746
#
#                                RevPctChange[t - 1]:LastEndPrice  F2[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.058135  -0.043878
# PctChange:MeanEndPrice@2Min                            0.223326   0.243899
# PctChange:MeanEndPrice@3Min                            0.369516   0.446452
# PctChange:MeanEndPrice@4Min                            0.432938   0.466612
# PctChange:MeanEndPrice@5Min                            0.429962   0.456543
# PctChange:MeanEndPrice@6Min                            0.467293   0.477390
# PctChange:MeanEndPrice@7Min                            0.511498   0.525365
# PctChange:MeanEndPrice@8Min                            0.516915   0.515672
# PctChange:MeanEndPrice@9Min                            0.496655   0.501964
# PctChange:MeanEndPrice@10Min                           0.484112   0.481306
# PctChange:MeanEndPrice@15Min                           0.544309   0.507375
# PctChange:MeanEndPrice@30Min                           0.529505   0.510033
# PctChange:MeanEndPrice@60Min                           0.583923   0.564795
# PctChange:MeanEndPrice@120Min                          0.600005   0.554101
# PctChange:MeanEndPrice@180Min                          0.590895   0.539447
# PctChange:MeanEndPrice@240Min                          0.657055   0.480505
# PctChange:MeanEndPrice@1D                              0.304310   0.234602
# PctChange:MeanEndPrice@2D                              0.432887   0.473809
# PctChange:MeanEndPrice@1W                              0.488633   0.569173
# PctChange:MeanEndPrice@2W                              0.458812   0.543242
#
#                                Direction2[t - 1]  F3[t - 1]  G1[t - 1]  \
# PctChange:MeanEndPrice@1Min            -0.044041  -0.043996  -0.043937
# PctChange:MeanEndPrice@2Min             0.268656   0.243620   0.219414
# PctChange:MeanEndPrice@3Min             0.379535   0.447419   0.332804
# PctChange:MeanEndPrice@4Min             0.436476   0.466332   0.379996
# PctChange:MeanEndPrice@5Min             0.440691   0.455466   0.386485
# PctChange:MeanEndPrice@6Min             0.471750   0.476017   0.420884
# PctChange:MeanEndPrice@7Min             0.516885   0.524448   0.430444
# PctChange:MeanEndPrice@8Min             0.521957   0.514255   0.468220
# PctChange:MeanEndPrice@9Min             0.500054   0.500331   0.435434
# PctChange:MeanEndPrice@10Min            0.487638   0.479811   0.429325
# PctChange:MeanEndPrice@15Min            0.546206   0.505333   0.480503
# PctChange:MeanEndPrice@30Min            0.531942   0.508160   0.471920
# PctChange:MeanEndPrice@60Min            0.586023   0.563057   0.526231
# PctChange:MeanEndPrice@120Min           0.602066   0.552350   0.478701
# PctChange:MeanEndPrice@180Min           0.585480   0.538341   0.432391
# PctChange:MeanEndPrice@240Min           0.642651   0.479579   0.445185
# PctChange:MeanEndPrice@1D               0.360993   0.233515   0.218872
# PctChange:MeanEndPrice@2D               0.479870   0.474900   0.288698
# PctChange:MeanEndPrice@1W               0.578466   0.569956   0.177724
# PctChange:MeanEndPrice@2W               0.553996   0.544419   0.385354
#
#                                G3[t - 1]  PctChange:LastEndPrice[t - 1]  \
# PctChange:MeanEndPrice@1Min    -0.039041                      -0.048899
# PctChange:MeanEndPrice@2Min     0.188602                       0.164457
# PctChange:MeanEndPrice@3Min     0.284271                       0.363713
# PctChange:MeanEndPrice@4Min     0.325611                       0.380441
# PctChange:MeanEndPrice@5Min     0.345750                       0.361401
# PctChange:MeanEndPrice@6Min     0.368116                       0.383651
# PctChange:MeanEndPrice@7Min     0.381381                       0.421565
# PctChange:MeanEndPrice@8Min     0.408759                       0.416825
# PctChange:MeanEndPrice@9Min     0.374597                       0.402850
# PctChange:MeanEndPrice@10Min    0.379193                       0.391853
# PctChange:MeanEndPrice@15Min    0.427339                       0.417568
# PctChange:MeanEndPrice@30Min    0.404509                       0.418019
# PctChange:MeanEndPrice@60Min    0.439577                       0.448745
# PctChange:MeanEndPrice@120Min   0.361368                       0.449825
# PctChange:MeanEndPrice@180Min   0.325007                       0.424021
# PctChange:MeanEndPrice@240Min   0.286904                       0.375896
# PctChange:MeanEndPrice@1D       0.169959                       0.255038
# PctChange:MeanEndPrice@2D       0.206909                       0.412889
# PctChange:MeanEndPrice@1W       0.162171                       0.475221
# PctChange:MeanEndPrice@2W       0.415073                       0.445095
#
#                                            ...               G2[t - 1]  \
# PctChange:MeanEndPrice@1Min                ...               -0.025848
# PctChange:MeanEndPrice@2Min                ...                0.165963
# PctChange:MeanEndPrice@3Min                ...                0.242359
# PctChange:MeanEndPrice@4Min                ...                0.286384
# PctChange:MeanEndPrice@5Min                ...                0.299391
# PctChange:MeanEndPrice@6Min                ...                0.313550
# PctChange:MeanEndPrice@7Min                ...                0.322283
# PctChange:MeanEndPrice@8Min                ...                0.334731
# PctChange:MeanEndPrice@9Min                ...                0.331195
# PctChange:MeanEndPrice@10Min               ...                0.332825
# PctChange:MeanEndPrice@15Min               ...                0.350268
# PctChange:MeanEndPrice@30Min               ...                0.337513
# PctChange:MeanEndPrice@60Min               ...                0.368857
# PctChange:MeanEndPrice@120Min              ...                0.309907
# PctChange:MeanEndPrice@180Min              ...                0.284835
# PctChange:MeanEndPrice@240Min              ...                0.266391
# PctChange:MeanEndPrice@1D                  ...                0.212276
# PctChange:MeanEndPrice@2D                  ...                0.164233
# PctChange:MeanEndPrice@1W                  ...                0.089730
# PctChange:MeanEndPrice@2W                  ...                0.422501
#
#                                F7[t - 1]  G4[t - 1]  \
# PctChange:MeanEndPrice@1Min    -0.026503  -0.023483
# PctChange:MeanEndPrice@2Min     0.207309   0.136051
# PctChange:MeanEndPrice@3Min     0.273922   0.200823
# PctChange:MeanEndPrice@4Min     0.309890   0.233416
# PctChange:MeanEndPrice@5Min     0.326282   0.249827
# PctChange:MeanEndPrice@6Min     0.340540   0.261761
# PctChange:MeanEndPrice@7Min     0.372832   0.269345
# PctChange:MeanEndPrice@8Min     0.342079   0.273265
# PctChange:MeanEndPrice@9Min     0.335596   0.270271
# PctChange:MeanEndPrice@10Min    0.325004   0.265940
# PctChange:MeanEndPrice@15Min    0.338435   0.277089
# PctChange:MeanEndPrice@30Min    0.333124   0.249840
# PctChange:MeanEndPrice@60Min    0.309798   0.261979
# PctChange:MeanEndPrice@120Min   0.334677   0.208829
# PctChange:MeanEndPrice@180Min   0.432413   0.181869
# PctChange:MeanEndPrice@240Min   0.438542   0.147441
# PctChange:MeanEndPrice@1D       0.209415   0.171857
# PctChange:MeanEndPrice@2D      -0.025054   0.171094
# PctChange:MeanEndPrice@1W       0.444715   0.128636
# PctChange:MeanEndPrice@2W       0.357787   0.441164
#
#                                RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice@1Min                                     -0.058135
# PctChange:MeanEndPrice@2Min                                      0.113732
# PctChange:MeanEndPrice@3Min                                      0.195872
# PctChange:MeanEndPrice@4Min                                      0.217401
# PctChange:MeanEndPrice@5Min                                      0.208762
# PctChange:MeanEndPrice@6Min                                      0.227590
# PctChange:MeanEndPrice@7Min                                      0.252963
# PctChange:MeanEndPrice@8Min                                      0.252307
# PctChange:MeanEndPrice@9Min                                      0.237795
# PctChange:MeanEndPrice@10Min                                     0.222683
# PctChange:MeanEndPrice@15Min                                     0.262237
# PctChange:MeanEndPrice@30Min                                     0.242764
# PctChange:MeanEndPrice@60Min                                     0.268925
# PctChange:MeanEndPrice@120Min                                    0.255436
# PctChange:MeanEndPrice@180Min                                    0.169476
# PctChange:MeanEndPrice@240Min                                    0.252468
# PctChange:MeanEndPrice@1D                                        0.148614
# PctChange:MeanEndPrice@2D                                        0.355087
# PctChange:MeanEndPrice@1W                                        0.188540
# PctChange:MeanEndPrice@2W                                        0.025034
#
#                                RevPctChange[t - 1]:MinPrice  \
# PctChange:MeanEndPrice@1Min                       -0.040189
# PctChange:MeanEndPrice@2Min                        0.061592
# PctChange:MeanEndPrice@3Min                        0.132835
# PctChange:MeanEndPrice@4Min                        0.164844
# PctChange:MeanEndPrice@5Min                        0.148942
# PctChange:MeanEndPrice@6Min                        0.165068
# PctChange:MeanEndPrice@7Min                        0.194866
# PctChange:MeanEndPrice@8Min                        0.212106
# PctChange:MeanEndPrice@9Min                        0.202288
# PctChange:MeanEndPrice@10Min                       0.196991
# PctChange:MeanEndPrice@15Min                       0.237927
# PctChange:MeanEndPrice@30Min                       0.201907
# PctChange:MeanEndPrice@60Min                       0.265072
# PctChange:MeanEndPrice@120Min                      0.250638
# PctChange:MeanEndPrice@180Min                      0.180837
# PctChange:MeanEndPrice@240Min                      0.183441
# PctChange:MeanEndPrice@1D                          0.084089
# PctChange:MeanEndPrice@2D                          0.397485
# PctChange:MeanEndPrice@1W                          0.091103
# PctChange:MeanEndPrice@2W                          0.129518
#
#                                RevPctChange[t - 1]:MeanEndPrice  \
# PctChange:MeanEndPrice@1Min                           -0.058135
# PctChange:MeanEndPrice@2Min                            0.105204
# PctChange:MeanEndPrice@3Min                            0.154092
# PctChange:MeanEndPrice@4Min                            0.182800
# PctChange:MeanEndPrice@5Min                            0.196382
# PctChange:MeanEndPrice@6Min                            0.205875
# PctChange:MeanEndPrice@7Min                            0.214009
# PctChange:MeanEndPrice@8Min                            0.212127
# PctChange:MeanEndPrice@9Min                            0.206838
# PctChange:MeanEndPrice@10Min                           0.200285
# PctChange:MeanEndPrice@15Min                           0.224284
# PctChange:MeanEndPrice@30Min                           0.216685
# PctChange:MeanEndPrice@60Min                           0.231966
# PctChange:MeanEndPrice@120Min                          0.195737
# PctChange:MeanEndPrice@180Min                          0.115035
# PctChange:MeanEndPrice@240Min                          0.129210
# PctChange:MeanEndPrice@1D                              0.181585
# PctChange:MeanEndPrice@2D                              0.391356
# PctChange:MeanEndPrice@1W                              0.139367
# PctChange:MeanEndPrice@2W                             -0.001493
#
#                                RevPctChange[t - 1]:MeanMaxMinPrice  \
# PctChange:MeanEndPrice@1Min                              -0.042481
# PctChange:MeanEndPrice@2Min                               0.052072
# PctChange:MeanEndPrice@3Min                               0.100225
# PctChange:MeanEndPrice@4Min                               0.132186
# PctChange:MeanEndPrice@5Min                               0.151863
# PctChange:MeanEndPrice@6Min                               0.165517
# PctChange:MeanEndPrice@7Min                               0.174130
# PctChange:MeanEndPrice@8Min                               0.178905
# PctChange:MeanEndPrice@9Min                               0.180865
# PctChange:MeanEndPrice@10Min                              0.176907
# PctChange:MeanEndPrice@15Min                              0.207149
# PctChange:MeanEndPrice@30Min                              0.208760
# PctChange:MeanEndPrice@60Min                              0.226598
# PctChange:MeanEndPrice@120Min                             0.193042
# PctChange:MeanEndPrice@180Min                             0.112055
# PctChange:MeanEndPrice@240Min                             0.127184
# PctChange:MeanEndPrice@1D                                 0.180128
# PctChange:MeanEndPrice@2D                                 0.390836
# PctChange:MeanEndPrice@1W                                 0.139627
# PctChange:MeanEndPrice@2W                                -0.001678
#
#                                RevPctChange[t - 1]:MeanAvg4Price  \
# PctChange:MeanEndPrice@1Min                            -0.042339
# PctChange:MeanEndPrice@2Min                             0.049232
# PctChange:MeanEndPrice@3Min                             0.097386
# PctChange:MeanEndPrice@4Min                             0.129911
# PctChange:MeanEndPrice@5Min                             0.151399
# PctChange:MeanEndPrice@6Min                             0.164416
# PctChange:MeanEndPrice@7Min                             0.173577
# PctChange:MeanEndPrice@8Min                             0.177894
# PctChange:MeanEndPrice@9Min                             0.180089
# PctChange:MeanEndPrice@10Min                            0.176410
# PctChange:MeanEndPrice@15Min                            0.206674
# PctChange:MeanEndPrice@30Min                            0.208507
# PctChange:MeanEndPrice@60Min                            0.226549
# PctChange:MeanEndPrice@120Min                           0.192790
# PctChange:MeanEndPrice@180Min                           0.111980
# PctChange:MeanEndPrice@240Min                           0.126991
# PctChange:MeanEndPrice@1D                               0.180043
# PctChange:MeanEndPrice@2D                               0.390622
# PctChange:MeanEndPrice@1W                               0.139565
# PctChange:MeanEndPrice@2W                              -0.001643
#
#                                RevPctChange[t - 1]:MeanStartEndPrice  \
# PctChange:MeanEndPrice@1Min                                -0.040873
# PctChange:MeanEndPrice@2Min                                 0.045965
# PctChange:MeanEndPrice@3Min                                 0.094141
# PctChange:MeanEndPrice@4Min                                 0.127312
# PctChange:MeanEndPrice@5Min                                 0.150698
# PctChange:MeanEndPrice@6Min                                 0.163131
# PctChange:MeanEndPrice@7Min                                 0.172869
# PctChange:MeanEndPrice@8Min                                 0.176768
# PctChange:MeanEndPrice@9Min                                 0.179218
# PctChange:MeanEndPrice@10Min                                0.175839
# PctChange:MeanEndPrice@15Min                                0.206159
# PctChange:MeanEndPrice@30Min                                0.208243
# PctChange:MeanEndPrice@60Min                                0.226498
# PctChange:MeanEndPrice@120Min                               0.192537
# PctChange:MeanEndPrice@180Min                               0.111903
# PctChange:MeanEndPrice@240Min                               0.126798
# PctChange:MeanEndPrice@1D                                   0.179957
# PctChange:MeanEndPrice@2D                                   0.390406
# PctChange:MeanEndPrice@1W                                   0.139503
# PctChange:MeanEndPrice@2W                                  -0.001608
#
#                                RevPctChange[t - 1]:MaxPrice
# PctChange:MeanEndPrice@1Min                       -0.036193
# PctChange:MeanEndPrice@2Min                        0.075007
# PctChange:MeanEndPrice@3Min                        0.126990
# PctChange:MeanEndPrice@4Min                        0.143626
# PctChange:MeanEndPrice@5Min                        0.159227
# PctChange:MeanEndPrice@6Min                        0.182958
# PctChange:MeanEndPrice@7Min                        0.195457
# PctChange:MeanEndPrice@8Min                        0.181348
# PctChange:MeanEndPrice@9Min                        0.184182
# PctChange:MeanEndPrice@10Min                       0.169255
# PctChange:MeanEndPrice@15Min                       0.204313
# PctChange:MeanEndPrice@30Min                       0.207961
# PctChange:MeanEndPrice@60Min                       0.211356
# PctChange:MeanEndPrice@120Min                      0.154757
# PctChange:MeanEndPrice@180Min                      0.133838
# PctChange:MeanEndPrice@240Min                      0.125898
# PctChange:MeanEndPrice@1D                          0.144621
# PctChange:MeanEndPrice@2D                          0.238338
# PctChange:MeanEndPrice@1W                          0.159706
# PctChange:MeanEndPrice@2W                          0.067552
#
# [20 rows x 22 columns]

# %%
corr_over_intervals('SIE')[x_features]
# Out:
#                                AdjustedPctChange[t - 1]  F1[t - 1]  \
# PctChange:MeanEndPrice@1Min                         NaN  -0.092423
# PctChange:MeanEndPrice@2Min                    0.298605   0.227853
# PctChange:MeanEndPrice@3Min                    0.570456   0.491523
# PctChange:MeanEndPrice@4Min                    0.594308   0.534169
# PctChange:MeanEndPrice@5Min                    0.576031   0.533269
# PctChange:MeanEndPrice@6Min                    0.598146   0.556198
# PctChange:MeanEndPrice@7Min                    0.578646   0.537384
# PctChange:MeanEndPrice@8Min                    0.619482   0.580045
# PctChange:MeanEndPrice@9Min                    0.622126   0.580829
# PctChange:MeanEndPrice@10Min                   0.615045   0.564001
# PctChange:MeanEndPrice@15Min                   0.625907   0.569026
# PctChange:MeanEndPrice@30Min                   0.633278   0.577330
# PctChange:MeanEndPrice@60Min                   0.685977   0.603765
# PctChange:MeanEndPrice@120Min                  0.716526   0.643537
# PctChange:MeanEndPrice@180Min                  0.634150   0.557158
# PctChange:MeanEndPrice@240Min                  0.750446   0.653465
# PctChange:MeanEndPrice@1D                      0.398602   0.370181
# PctChange:MeanEndPrice@2D                      0.626521   0.533983
# PctChange:MeanEndPrice@1W                      0.753739   0.730202
# PctChange:MeanEndPrice@2W                      0.800761   0.794800
#
#                                H1@WithNorm(MeanEndPrice)[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.092423
# PctChange:MeanEndPrice@2Min                            0.227863
# PctChange:MeanEndPrice@3Min                            0.491597
# PctChange:MeanEndPrice@4Min                            0.534168
# PctChange:MeanEndPrice@5Min                            0.533188
# PctChange:MeanEndPrice@6Min                            0.556089
# PctChange:MeanEndPrice@7Min                            0.537404
# PctChange:MeanEndPrice@8Min                            0.579910
# PctChange:MeanEndPrice@9Min                            0.580725
# PctChange:MeanEndPrice@10Min                           0.563964
# PctChange:MeanEndPrice@15Min                           0.568973
# PctChange:MeanEndPrice@30Min                           0.577224
# PctChange:MeanEndPrice@60Min                           0.603460
# PctChange:MeanEndPrice@120Min                          0.643001
# PctChange:MeanEndPrice@180Min                          0.556503
# PctChange:MeanEndPrice@240Min                          0.652659
# PctChange:MeanEndPrice@1D                              0.369403
# PctChange:MeanEndPrice@2D                              0.531246
# PctChange:MeanEndPrice@1W                              0.730364
# PctChange:MeanEndPrice@2W                              0.792258
#
#                                RevPctChange[t - 1]:LastEndPrice  F2[t - 1]  \
# PctChange:MeanEndPrice@1Min                           -0.087856  -0.084036
# PctChange:MeanEndPrice@2Min                            0.191619   0.200317
# PctChange:MeanEndPrice@3Min                            0.340438   0.470085
# PctChange:MeanEndPrice@4Min                            0.410578   0.498187
# PctChange:MeanEndPrice@5Min                            0.428651   0.494623
# PctChange:MeanEndPrice@6Min                            0.462269   0.503052
# PctChange:MeanEndPrice@7Min                            0.473308   0.481754
# PctChange:MeanEndPrice@8Min                            0.506192   0.512900
# PctChange:MeanEndPrice@9Min                            0.497267   0.526866
# PctChange:MeanEndPrice@10Min                           0.497268   0.489266
# PctChange:MeanEndPrice@15Min                           0.522157   0.484980
# PctChange:MeanEndPrice@30Min                           0.528904   0.485131
# PctChange:MeanEndPrice@60Min                           0.602329   0.504683
# PctChange:MeanEndPrice@120Min                          0.619432   0.540821
# PctChange:MeanEndPrice@180Min                          0.560992   0.440814
# PctChange:MeanEndPrice@240Min                          0.718147   0.527016
# PctChange:MeanEndPrice@1D                              0.360162   0.330838
# PctChange:MeanEndPrice@2D                              0.524747   0.494016
# PctChange:MeanEndPrice@1W                              0.644347   0.674258
# PctChange:MeanEndPrice@2W                              0.615222   0.636734
#
#                                Direction2[t - 1]  F3[t - 1]  G1[t - 1]  \
# PctChange:MeanEndPrice@1Min            -0.084351  -0.084010  -0.084020
# PctChange:MeanEndPrice@2Min             0.232490   0.200306   0.140958
# PctChange:MeanEndPrice@3Min             0.353936   0.472140   0.232720
# PctChange:MeanEndPrice@4Min             0.423191   0.499090   0.287541
# PctChange:MeanEndPrice@5Min             0.441942   0.494576   0.316516
# PctChange:MeanEndPrice@6Min             0.471614   0.502350   0.340911
# PctChange:MeanEndPrice@7Min             0.498598   0.480950   0.319848
# PctChange:MeanEndPrice@8Min             0.510449   0.511388   0.381618
# PctChange:MeanEndPrice@9Min             0.503129   0.525878   0.357355
# PctChange:MeanEndPrice@10Min            0.501323   0.487324   0.374626
# PctChange:MeanEndPrice@15Min            0.522298   0.482509   0.399265
# PctChange:MeanEndPrice@30Min            0.528506   0.482517   0.405209
# PctChange:MeanEndPrice@60Min            0.603756   0.501164   0.417851
# PctChange:MeanEndPrice@120Min           0.619806   0.538665   0.325440
# PctChange:MeanEndPrice@180Min           0.562089   0.438345   0.204329
# PctChange:MeanEndPrice@240Min           0.719841   0.524427   0.103253
# PctChange:MeanEndPrice@1D               0.450775   0.329854   0.093114
# PctChange:MeanEndPrice@2D               0.577598   0.494395   0.114025
# PctChange:MeanEndPrice@1W               0.679218   0.673743   0.000475
# PctChange:MeanEndPrice@2W               0.644858   0.640392  -0.010037
#
#                                G3[t - 1]  PctChange:LastEndPrice[t - 1]  \
# PctChange:MeanEndPrice@1Min    -0.092423                      -0.079444
# PctChange:MeanEndPrice@2Min     0.108513                       0.142136
# PctChange:MeanEndPrice@3Min     0.188142                       0.388743
# PctChange:MeanEndPrice@4Min     0.231346                       0.404286
# PctChange:MeanEndPrice@5Min     0.263340                       0.398090
# PctChange:MeanEndPrice@6Min     0.285162                       0.413045
# PctChange:MeanEndPrice@7Min     0.265050                       0.385788
# PctChange:MeanEndPrice@8Min     0.317593                       0.429069
# PctChange:MeanEndPrice@9Min     0.298075                       0.436417
# PctChange:MeanEndPrice@10Min    0.317268                       0.410471
# PctChange:MeanEndPrice@15Min    0.328157                       0.406497
# PctChange:MeanEndPrice@30Min    0.322228                       0.420822
# PctChange:MeanEndPrice@60Min    0.319424                       0.431320
# PctChange:MeanEndPrice@120Min   0.234700                       0.465394
# PctChange:MeanEndPrice@180Min   0.126609                       0.389121
# PctChange:MeanEndPrice@240Min   0.026419                       0.412452
# PctChange:MeanEndPrice@1D       0.018777                       0.276413
# PctChange:MeanEndPrice@2D       0.081695                       0.404922
# PctChange:MeanEndPrice@1W       0.078159                       0.649266
# PctChange:MeanEndPrice@2W      -0.033429                       0.609172
#
#                                            ...               G2[t - 1]  \
# PctChange:MeanEndPrice@1Min                ...               -0.080969
# PctChange:MeanEndPrice@2Min                ...                0.106158
# PctChange:MeanEndPrice@3Min                ...                0.187207
# PctChange:MeanEndPrice@4Min                ...                0.232097
# PctChange:MeanEndPrice@5Min                ...                0.262333
# PctChange:MeanEndPrice@6Min                ...                0.280586
# PctChange:MeanEndPrice@7Min                ...                0.276517
# PctChange:MeanEndPrice@8Min                ...                0.312338
# PctChange:MeanEndPrice@9Min                ...                0.305613
# PctChange:MeanEndPrice@10Min               ...                0.308915
# PctChange:MeanEndPrice@15Min               ...                0.320233
# PctChange:MeanEndPrice@30Min               ...                0.320019
# PctChange:MeanEndPrice@60Min               ...                0.343094
# PctChange:MeanEndPrice@120Min              ...                0.291429
# PctChange:MeanEndPrice@180Min              ...                0.186463
# PctChange:MeanEndPrice@240Min              ...                0.117524
# PctChange:MeanEndPrice@1D                  ...                0.178635
# PctChange:MeanEndPrice@2D                  ...                0.195024
# PctChange:MeanEndPrice@1W                  ...               -0.050289
# PctChange:MeanEndPrice@2W                  ...               -0.138770
#
#                                F7[t - 1]  G4[t - 1]  \
# PctChange:MeanEndPrice@1Min    -0.052195  -0.091907
# PctChange:MeanEndPrice@2Min     0.171958   0.065779
# PctChange:MeanEndPrice@3Min     0.238747   0.135360
# PctChange:MeanEndPrice@4Min     0.268620   0.168284
# PctChange:MeanEndPrice@5Min     0.289055   0.196944
# PctChange:MeanEndPrice@6Min     0.297252   0.216987
# PctChange:MeanEndPrice@7Min     0.305627   0.198839
# PctChange:MeanEndPrice@8Min     0.307584   0.237347
# PctChange:MeanEndPrice@9Min     0.300351   0.237133
# PctChange:MeanEndPrice@10Min    0.299049   0.239798
# PctChange:MeanEndPrice@15Min    0.322145   0.248031
# PctChange:MeanEndPrice@30Min    0.322265   0.239393
# PctChange:MeanEndPrice@60Min    0.332438   0.257131
# PctChange:MeanEndPrice@120Min   0.355603   0.219808
# PctChange:MeanEndPrice@180Min   0.362745   0.109438
# PctChange:MeanEndPrice@240Min   0.357899   0.053437
# PctChange:MeanEndPrice@1D       0.211399   0.020678
# PctChange:MeanEndPrice@2D       0.059782   0.100547
# PctChange:MeanEndPrice@1W       0.522104  -0.004965
# PctChange:MeanEndPrice@2W       0.483994  -0.176374
#
#                                RevPctChange[t - 1]:VolumeWeightedEndPrice  \
# PctChange:MeanEndPrice@1Min                                     -0.087856
# PctChange:MeanEndPrice@2Min                                      0.091896
# PctChange:MeanEndPrice@3Min                                      0.179187
# PctChange:MeanEndPrice@4Min                                      0.215712
# PctChange:MeanEndPrice@5Min                                      0.217533
# PctChange:MeanEndPrice@6Min                                      0.229235
# PctChange:MeanEndPrice@7Min                                      0.236555
# PctChange:MeanEndPrice@8Min                                      0.257562
# PctChange:MeanEndPrice@9Min                                      0.254477
# PctChange:MeanEndPrice@10Min                                     0.241582
# PctChange:MeanEndPrice@15Min                                     0.249592
# PctChange:MeanEndPrice@30Min                                     0.264796
# PctChange:MeanEndPrice@60Min                                     0.297294
# PctChange:MeanEndPrice@120Min                                    0.237375
# PctChange:MeanEndPrice@180Min                                    0.205742
# PctChange:MeanEndPrice@240Min                                    0.387777
# PctChange:MeanEndPrice@1D                                        0.213199
# PctChange:MeanEndPrice@2D                                        0.295566
# PctChange:MeanEndPrice@1W                                        0.273794
# PctChange:MeanEndPrice@2W                                        0.079988
#
#                                RevPctChange[t - 1]:MinPrice  \
# PctChange:MeanEndPrice@1Min                       -0.051012
# PctChange:MeanEndPrice@2Min                        0.058992
# PctChange:MeanEndPrice@3Min                        0.120468
# PctChange:MeanEndPrice@4Min                        0.159722
# PctChange:MeanEndPrice@5Min                        0.157345
# PctChange:MeanEndPrice@6Min                        0.182452
# PctChange:MeanEndPrice@7Min                        0.201566
# PctChange:MeanEndPrice@8Min                        0.216119
# PctChange:MeanEndPrice@9Min                        0.221069
# PctChange:MeanEndPrice@10Min                       0.212065
# PctChange:MeanEndPrice@15Min                       0.212325
# PctChange:MeanEndPrice@30Min                       0.208186
# PctChange:MeanEndPrice@60Min                       0.278263
# PctChange:MeanEndPrice@120Min                      0.215865
# PctChange:MeanEndPrice@180Min                      0.204192
# PctChange:MeanEndPrice@240Min                      0.204521
# PctChange:MeanEndPrice@1D                          0.203176
# PctChange:MeanEndPrice@2D                          0.472339
# PctChange:MeanEndPrice@1W                          0.371375
# PctChange:MeanEndPrice@2W                          0.306928
#
#                                RevPctChange[t - 1]:MeanEndPrice  \
# PctChange:MeanEndPrice@1Min                           -0.087856
# PctChange:MeanEndPrice@2Min                            0.081400
# PctChange:MeanEndPrice@3Min                            0.142871
# PctChange:MeanEndPrice@4Min                            0.171856
# PctChange:MeanEndPrice@5Min                            0.183931
# PctChange:MeanEndPrice@6Min                            0.196093
# PctChange:MeanEndPrice@7Min                            0.202792
# PctChange:MeanEndPrice@8Min                            0.220359
# PctChange:MeanEndPrice@9Min                            0.215525
# PctChange:MeanEndPrice@10Min                           0.213481
# PctChange:MeanEndPrice@15Min                           0.223325
# PctChange:MeanEndPrice@30Min                           0.237969
# PctChange:MeanEndPrice@60Min                           0.242056
# PctChange:MeanEndPrice@120Min                          0.176908
# PctChange:MeanEndPrice@180Min                          0.178931
# PctChange:MeanEndPrice@240Min                          0.343719
# PctChange:MeanEndPrice@1D                              0.239912
# PctChange:MeanEndPrice@2D                              0.259852
# PctChange:MeanEndPrice@1W                              0.219268
# PctChange:MeanEndPrice@2W                              0.039846
#
#                                RevPctChange[t - 1]:MeanMaxMinPrice  \
# PctChange:MeanEndPrice@1Min                              -0.053637
# PctChange:MeanEndPrice@2Min                               0.045812
# PctChange:MeanEndPrice@3Min                               0.098049
# PctChange:MeanEndPrice@4Min                               0.133369
# PctChange:MeanEndPrice@5Min                               0.145491
# PctChange:MeanEndPrice@6Min                               0.163087
# PctChange:MeanEndPrice@7Min                               0.174863
# PctChange:MeanEndPrice@8Min                               0.194195
# PctChange:MeanEndPrice@9Min                               0.193067
# PctChange:MeanEndPrice@10Min                              0.192998
# PctChange:MeanEndPrice@15Min                              0.207799
# PctChange:MeanEndPrice@30Min                              0.229599
# PctChange:MeanEndPrice@60Min                              0.237020
# PctChange:MeanEndPrice@120Min                             0.172680
# PctChange:MeanEndPrice@180Min                             0.175577
# PctChange:MeanEndPrice@240Min                             0.342207
# PctChange:MeanEndPrice@1D                                 0.241022
# PctChange:MeanEndPrice@2D                                 0.259314
# PctChange:MeanEndPrice@1W                                 0.218759
# PctChange:MeanEndPrice@2W                                 0.040175
#
#                                RevPctChange[t - 1]:MeanAvg4Price  \
# PctChange:MeanEndPrice@1Min                            -0.060720
# PctChange:MeanEndPrice@2Min                             0.042929
# PctChange:MeanEndPrice@3Min                             0.096265
# PctChange:MeanEndPrice@4Min                             0.131304
# PctChange:MeanEndPrice@5Min                             0.144391
# PctChange:MeanEndPrice@6Min                             0.162078
# PctChange:MeanEndPrice@7Min                             0.174314
# PctChange:MeanEndPrice@8Min                             0.193187
# PctChange:MeanEndPrice@9Min                             0.192377
# PctChange:MeanEndPrice@10Min                            0.192655
# PctChange:MeanEndPrice@15Min                            0.207471
# PctChange:MeanEndPrice@30Min                            0.229355
# PctChange:MeanEndPrice@60Min                            0.236653
# PctChange:MeanEndPrice@120Min                           0.172624
# PctChange:MeanEndPrice@180Min                           0.175480
# PctChange:MeanEndPrice@240Min                           0.342153
# PctChange:MeanEndPrice@1D                               0.240255
# PctChange:MeanEndPrice@2D                               0.258675
# PctChange:MeanEndPrice@1W                               0.218959
# PctChange:MeanEndPrice@2W                               0.040150
#
#                                RevPctChange[t - 1]:MeanStartEndPrice  \
# PctChange:MeanEndPrice@1Min                                -0.066340
# PctChange:MeanEndPrice@2Min                                 0.039638
# PctChange:MeanEndPrice@3Min                                 0.094003
# PctChange:MeanEndPrice@4Min                                 0.128825
# PctChange:MeanEndPrice@5Min                                 0.142989
# PctChange:MeanEndPrice@6Min                                 0.160827
# PctChange:MeanEndPrice@7Min                                 0.173585
# PctChange:MeanEndPrice@8Min                                 0.192005
# PctChange:MeanEndPrice@9Min                                 0.191554
# PctChange:MeanEndPrice@10Min                                0.192203
# PctChange:MeanEndPrice@15Min                                0.207088
# PctChange:MeanEndPrice@30Min                                0.229094
# PctChange:MeanEndPrice@60Min                                0.236280
# PctChange:MeanEndPrice@120Min                               0.172567
# PctChange:MeanEndPrice@180Min                               0.175383
# PctChange:MeanEndPrice@240Min                               0.342099
# PctChange:MeanEndPrice@1D                                   0.239484
# PctChange:MeanEndPrice@2D                                   0.258034
# PctChange:MeanEndPrice@1W                                   0.219159
# PctChange:MeanEndPrice@2W                                   0.040125
#
#                                RevPctChange[t - 1]:MaxPrice
# PctChange:MeanEndPrice@1Min                       -0.045660
# PctChange:MeanEndPrice@2Min                        0.062606
# PctChange:MeanEndPrice@3Min                        0.119281
# PctChange:MeanEndPrice@4Min                        0.147028
# PctChange:MeanEndPrice@5Min                        0.143154
# PctChange:MeanEndPrice@6Min                        0.158972
# PctChange:MeanEndPrice@7Min                        0.173407
# PctChange:MeanEndPrice@8Min                        0.182721
# PctChange:MeanEndPrice@9Min                        0.179974
# PctChange:MeanEndPrice@10Min                       0.175417
# PctChange:MeanEndPrice@15Min                       0.195692
# PctChange:MeanEndPrice@30Min                       0.207557
# PctChange:MeanEndPrice@60Min                       0.203674
# PctChange:MeanEndPrice@120Min                      0.218691
# PctChange:MeanEndPrice@180Min                      0.197821
# PctChange:MeanEndPrice@240Min                      0.435201
# PctChange:MeanEndPrice@1D                          0.055209
# PctChange:MeanEndPrice@2D                          0.114883
# PctChange:MeanEndPrice@1W                          0.119269
# PctChange:MeanEndPrice@2W                         -0.011775
#
# [20 rows x 22 columns]

# %%
# corr_over_intervals('SAP')

# %% [markdown]
# The reasons for the strong correlations is due to averaging.
# We make an experiment to check the correlation with `MaxPrice` which uses only `MaxPrice`
# and `Direction` which uses only `EndPrice` and `StartPrice`.

# %%
single_stock = prepare_single_stock('BMW', '1D')
pd.DataFrame({
    'PctChange:MaxPrice': single_stock['PctChange:MaxPrice'],
    'Direction[t + 1]': single_stock['Direction'].shift(-1),   
    'Direction[t - 0]': single_stock['Direction'],        
    'Direction[t - 1]': single_stock['Direction[t - 1]'],
    'Direction[t - 2]': single_stock['Direction[t - 1]'].shift(1),
    'Direction[t - 3]': single_stock['Direction[t - 1]'].shift(2),
    'Direction[t - 4]': single_stock['Direction[t - 1]'].shift(3),
    'Direction[t - 4]': single_stock['Direction[t - 1]'].shift(4)    
}).corr()[['PctChange:MaxPrice']]
# Out:
#                     PctChange:MaxPrice
# Direction[t + 1]             -0.012476
# Direction[t - 0]              0.462436
# Direction[t - 1]              0.375247
# Direction[t - 2]              0.065301
# Direction[t - 3]             -0.007288
# Direction[t - 4]             -0.042227
# PctChange:MaxPrice            1.000000

# %%
single_stock = prepare_single_stock('BMW', '1D')
pd.DataFrame({
    'PctChange:LastEndPrice': single_stock['PctChange:LastEndPrice'],
    'Direction[t + 1]': single_stock['Direction'].shift(-1),   
    'Direction[t - 0]': single_stock['Direction'],        
    'Direction[t - 1]': single_stock['Direction[t - 1]'],
    'Direction[t - 2]': single_stock['Direction[t - 1]'].shift(1),
    'Direction[t - 3]': single_stock['Direction[t - 1]'].shift(2),
    'Direction[t - 4]': single_stock['Direction[t - 1]'].shift(3),
    'Direction[t - 4]': single_stock['Direction[t - 1]'].shift(4)    
}).corr()[['PctChange:LastEndPrice']]
# Out:
#                         PctChange:LastEndPrice
# Direction[t + 1]                      0.027184
# Direction[t - 0]                      0.732582
# Direction[t - 1]                      0.040058
# Direction[t - 2]                      0.119437
# Direction[t - 3]                     -0.032281
# Direction[t - 4]                     -0.037653
# PctChange:LastEndPrice                1.000000

# %% [markdown]
# The reason that there is no correlation between period `(t)` and `(t - 2)` is related to the normalization we do in percent change. We can verify this independently next.

# %%
single_stock = prepare_single_stock('BMW', '1D')
last_end_price = single_stock['PctChange:LastEndPrice']
pd.DataFrame({
    'PctChange:LastEndPrice': last_end_price,       
    'PctChange:LastEndPrice[t - 1]': last_end_price.shift(1),
    'PctChange:LastEndPrice[t - 2]': last_end_price.shift(2),
    'PctChange:LastEndPrice[t - 3]': last_end_price.shift(3),
    'PctChange:LastEndPrice[t - 4]': last_end_price.shift(4)    
}).corr()[['PctChange:LastEndPrice']]
# Out:
#                                PctChange:LastEndPrice
# PctChange:LastEndPrice                       1.000000
# PctChange:LastEndPrice[t - 1]                0.133811
# PctChange:LastEndPrice[t - 2]                0.067861
# PctChange:LastEndPrice[t - 3]               -0.039186
# PctChange:LastEndPrice[t - 4]               -0.015114

# %% [markdown]
# Once we start normalizing the features in the same way, we find that past periods also exibit
# correlations to the present

# %%
single_stock = prepare_single_stock('BMW', '1D')
last_end_price = single_stock['PctChange:LastEndPrice']
pd.DataFrame({
    'PctChange:LastEndPrice': last_end_price,       
    rev_pct_change_of_at_t('LastEndPrice', 1): single_stock[rev_pct_change_of_at_t('LastEndPrice', 1)],
    rev_pct_change_of_at_t('LastEndPrice', 2): single_stock[rev_pct_change_of_at_t('LastEndPrice', 2)],
    rev_pct_change_of_at_t('LastEndPrice', 3): single_stock[rev_pct_change_of_at_t('LastEndPrice', 3)]
}).corr()[['PctChange:LastEndPrice']]
# Out:
#                                   PctChange:LastEndPrice
# PctChange:LastEndPrice                          1.000000
# RevPctChange[t - 1]:LastEndPrice                0.124178
# RevPctChange[t - 2]:LastEndPrice                0.144278
# RevPctChange[t - 3]:LastEndPrice                0.123414

# %%
single_stock = prepare_single_stock('BMW', '1D')
mean_end_price = single_stock['PctChange:MeanEndPrice']
pd.DataFrame({
    'PctChange:MeanEndPrice': mean_end_price,       
    rev_pct_change_of_at_t('MeanEndPrice', 1): single_stock[rev_pct_change_of_at_t('MeanEndPrice', 1)],
    rev_pct_change_of_at_t('MeanEndPrice', 2): single_stock[rev_pct_change_of_at_t('MeanEndPrice', 2)],
    rev_pct_change_of_at_t('MeanEndPrice', 3): single_stock[rev_pct_change_of_at_t('MeanEndPrice', 3)]
}).corr()[['PctChange:MeanEndPrice']]
# Out:
#                                   PctChange:MeanEndPrice
# PctChange:MeanEndPrice                          1.000000
# RevPctChange[t - 1]:MeanEndPrice                0.181585
# RevPctChange[t - 2]:MeanEndPrice                0.144456
# RevPctChange[t - 3]:MeanEndPrice                0.175877

# %% [markdown]
# If we experiment with the same feature, but normalized differently we:
# - are not going to see correlations beyond `(t - 1)` when different normalization is used
# - we may see correlations with the past when the same normalization is used

# %%
single_stock = prepare_single_stock('BMW', '1D')
mean_end_price = single_stock['PctChange:MeanEndPrice']
pd.DataFrame({
    'PctChange:MeanEndPrice': mean_end_price,       
    norm_feature('H1', 1, 'MeanEndPrice'): single_stock[norm_feature('H1', 1, 'MeanEndPrice')],
    norm_feature('H1', 2, 'MeanEndPrice'): single_stock[norm_feature('H1', 2, 'MeanEndPrice')],
    norm_feature('H1', 3, 'MeanEndPrice'): single_stock[norm_feature('H1', 3, 'MeanEndPrice')],
    norm_feature('H1', 4, 'MeanEndPrice'): single_stock[norm_feature('H1', 4, 'MeanEndPrice')],
    'F1[t - 1]': single_stock['F1[t - 1]'],
    'F1[t - 2]': single_stock['F1[t - 1]'].shift(1),
    'F1[t - 3]': single_stock['F1[t - 1]'].shift(2),
    'F1[t - 4]': single_stock['F1[t - 1]'].shift(3)  
}).corr()[['PctChange:MeanEndPrice']]
# Out:
#                                   PctChange:MeanEndPrice
# F1[t - 1]                                       0.379122
# F1[t - 2]                                       0.065195
# F1[t - 3]                                       0.001757
# F1[t - 4]                                       0.022977
# H1@WithNorm(MeanEndPrice)[t - 1]                0.378796
# H1@WithNorm(MeanEndPrice)[t - 2]                0.051776
# H1@WithNorm(MeanEndPrice)[t - 3]               -0.013097
# H1@WithNorm(MeanEndPrice)[t - 4]                0.277385
# PctChange:MeanEndPrice                          1.000000

# %% [markdown]
# ## Log of return
# In their [demo notebook](https://github.com/googledatalab/notebooks/blob/master/samples/TensorFlow/Machine%20Learning%20with%20Financial%20Data.ipynb) Google Cloud computes a feature that they call log return. This feature is:
#
# ```
# log(Price:X[t]/Price:X[t - 1])
# ```
# for some version of price X.
#
# We explore this feature below. We find that when `Mean` of price is used, this feature correlates well
# with various predictors, but when the `Last` of price is used, this feature does not correlate very well

# %%
single_stock = prepare_single_stock('SIE', '30Min')
corr_log_return(single_stock, 'MeanEndPrice')
# Out:
#                         AdjLogReturn:LastEndPrice  \
# LogReturn:MeanEndPrice                    0.89294
#
#                         AdjLogReturn:LastEndPrice[t - 1]  \
# LogReturn:MeanEndPrice                          0.633228
#
#                         AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# LogReturn:MeanEndPrice                  0.633234            0.48406
#
#                         Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# LogReturn:MeanEndPrice           0.528475   0.577222   0.485085   0.482471
#
#                         F4[t - 1]  F5[t - 1]               ...                \
# LogReturn:MeanEndPrice   0.090951   0.099265               ...
#
#                         RevPctChange[t - 4]:MaxPrice  \
# LogReturn:MeanEndPrice                      0.066983
#
#                         RevPctChange[t - 4]:MeanAvg4Price  \
# LogReturn:MeanEndPrice                           0.065278
#
#                         RevPctChange[t - 4]:MeanEndPrice  \
# LogReturn:MeanEndPrice                           0.06894
#
#                         RevPctChange[t - 4]:MeanMaxMinPrice  \
# LogReturn:MeanEndPrice                             0.065479
#
#                         RevPctChange[t - 4]:MeanStartEndPrice  \
# LogReturn:MeanEndPrice                               0.065075
#
#                         RevPctChange[t - 4]:MedianEndPrice  \
# LogReturn:MeanEndPrice                            0.063838
#
#                         RevPctChange[t - 4]:MinPrice  \
# LogReturn:MeanEndPrice                      0.087899
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# LogReturn:MeanEndPrice                        -0.029496
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# LogReturn:MeanEndPrice                                    0.083471
#
#                         VolumeWeightedPctChange[t - 1]
# LogReturn:MeanEndPrice                         0.44998
#
# [1 rows x 95 columns]

# %%
single_stock = prepare_single_stock('SIE', '30Min')
corr_log_return(single_stock, 'LastEndPrice')
# Out:
#                         AdjLogReturn:LastEndPrice  \
# LogReturn:LastEndPrice                    0.87536
#
#                         AdjLogReturn:LastEndPrice[t - 1]  \
# LogReturn:LastEndPrice                          -0.04484
#
#                         AdjustedPctChange[t - 1]  Direction1[t - 1]  \
# LogReturn:LastEndPrice                 -0.044811          -0.011142
#
#                         Direction2[t - 1]  F1[t - 1]  F2[t - 1]  F3[t - 1]  \
# LogReturn:LastEndPrice          -0.029627  -0.027358   -0.01124  -0.010971
#
#                         F4[t - 1]  F5[t - 1]               ...                \
# LogReturn:LastEndPrice   0.020748  -0.027203               ...
#
#                         RevPctChange[t - 4]:MaxPrice  \
# LogReturn:LastEndPrice                     -0.038851
#
#                         RevPctChange[t - 4]:MeanAvg4Price  \
# LogReturn:LastEndPrice                          -0.021236
#
#                         RevPctChange[t - 4]:MeanEndPrice  \
# LogReturn:LastEndPrice                         -0.021244
#
#                         RevPctChange[t - 4]:MeanMaxMinPrice  \
# LogReturn:LastEndPrice                            -0.021247
#
#                         RevPctChange[t - 4]:MeanStartEndPrice  \
# LogReturn:LastEndPrice                              -0.021224
#
#                         RevPctChange[t - 4]:MedianEndPrice  \
# LogReturn:LastEndPrice                           -0.015875
#
#                         RevPctChange[t - 4]:MinPrice  \
# LogReturn:LastEndPrice                     -0.010987
#
#                         RevPctChange[t - 4]:StdEndPrice  \
# LogReturn:LastEndPrice                        -0.021412
#
#                         RevPctChange[t - 4]:VolumeWeightedEndPrice  \
# LogReturn:LastEndPrice                                   -0.022538
#
#                         VolumeWeightedPctChange[t - 1]
# LogReturn:LastEndPrice                         -0.0137
#
# [1 rows x 95 columns]

# %% [markdown]
# When we examine correlations of LogReturn we find that beyond `(t - 1)` there are no correlations.
# Google cloud also reports the same. As we explained, the reason is due to different normalizaiton
# in different periods.

# %%
single_stock = prepare_single_stock('SIE', '30Min')
mean_end_price = single_stock['LogReturn:MeanEndPrice']
pd.DataFrame({
    'LogReturn:MeanEndPrice': mean_end_price,     
    'LogReturn:MeanEndPrice[t - 1]': single_stock['LogReturn:MeanEndPrice[t - 1]'],
    'LogReturn:MeanEndPrice[t - 2]': single_stock['LogReturn:MeanEndPrice[t - 1]'].shift(1),
    'LogReturn:MeanEndPrice[t - 3]': single_stock['LogReturn:MeanEndPrice[t - 1]'].shift(2),
    'LogReturn:MeanEndPrice[t - 4]': single_stock['LogReturn:MeanEndPrice[t - 1]'].shift(3)  
}).corr()[['LogReturn:MeanEndPrice']]
# Out:
#                                LogReturn:MeanEndPrice
# LogReturn:MeanEndPrice                       1.000000
# LogReturn:MeanEndPrice[t - 1]                0.238046
# LogReturn:MeanEndPrice[t - 2]               -0.008179
# LogReturn:MeanEndPrice[t - 3]               -0.035098
# LogReturn:MeanEndPrice[t - 4]               -0.021521

# %% [markdown]
# ## On the relationship between percent change and log return

# %% [markdown]
# Some people prefer to model percent change, while others prefer to model log return.
# We find that both a suspiciously correlated. It turns that there is an approximate
# mathematical equality that relates them
#
# ```
# log(a/b) = log[ (b + (a - b))/b ] = log(1 + pct_change) = pct_change,
# where pct_change = (a - b)/b
#
# log(1 + x) = x is an approximate equality when x is close to zero
# ```

# %% [markdown]
# # The variance of predicted features

# %% [markdown]
# Below we study the variance of a number of functions:
#
# ```
# func = (price - anchor)/anchor
# ```
# for different choices of price and anchor.
#
# ```
# end to end: (end_price[t] - end_price[t - 1])/end_price[t - 1]
# end to mean: (end_price[t] - mean_price[t - 1])/mean_price[t - 1]
# mean to end: (mean_price[t] - end_price[t - 1])/end_price[t - 1]
# mean to mean: (mean_price[t] - mean_price[t - 1])/mean_price[t - 1]
# mean to prev mean: (mean_price[t] - mean_price[t - 2])/mean_price[t - 2]
# ```
#
# The idea is that we use the following method to estimate mean price in minutes 15 to 20.
# - estimate the mean price in minutes 10 to 15, call it `M[1]`
# - estimate the mean price in minutes 10 to 20, call it `M[2]`
# - compute `M[2] - M[1]`, the second minus the first
#
# ## Some observations
#
# - As the anchor goes further back in time from the predicted price, the variance increases

# %%
intervals = ['1Min', '2Min', '3Min', '4Min', '5Min', '6Min', '7Min', '8Min', '9Min', '10Min', 
             '15Min', '30Min', '60Min', '120Min', '180Min', '240Min',
             '1D', '2D', '1W', '2W', '1M', '2M', '3M', '6M']
rows = []
for i in intervals:
    single_stock = prepare_single_stock('SIE', i)
    e = single_stock['LastEndPrice']
    n = single_stock['LastEndPrice'].shift(1)
    end_to_end = (e - n)/n
    
    m = single_stock['MeanAvg4Price']
    end_to_mean = (e - m.shift(1))/m.shift(1)  
    mean_to_mean = (m - m.shift(1))/m.shift(1)
    mean_to_prev_mean = (m - m.shift(2))/m.shift(2) 
    mean_to_end = (m - e)/e
    s1, s2 = end_to_mean.std(), indirect2.std()
    indirect_std = np.sqrt(s1*s1 + s2*s2)
    rows.append((i, end_to_end.std(), indirect_std, end_to_mean.std(), mean_to_mean.std(), mean_to_prev_mean.std(), mean_to_end.std()))

# %%
pd.DataFrame(rows, columns = [
    "interval", "end_to_end", "indirect", "end to mean", "mean to mean", "mean to prev mean", "mean to end"
])
# Out:
#    interval  end_to_end  indirect  end to mean  mean to mean  \
# 0      1Min    0.000632  0.033256     0.000652      0.000551
# 1      2Min    0.000837  0.033261     0.000884      0.000747
# 2      3Min    0.001023  0.033268     0.001112      0.000859
# 3      4Min    0.001156  0.033273     0.001253      0.000980
# 4      5Min    0.001305  0.033279     0.001396      0.001100
# 5      6Min    0.001404  0.033284     0.001506      0.001207
# 6      7Min    0.001519  0.033290     0.001631      0.001312
# 7      8Min    0.001604  0.033294     0.001725      0.001387
# 8      9Min    0.001700  0.033300     0.001823      0.001460
# 9     10Min    0.001789  0.033305     0.001918      0.001569
# 10    15Min    0.002179  0.033332     0.002337      0.001933
# 11    30Min    0.003095  0.033412     0.003285      0.002737
# 12    60Min    0.004307  0.033566     0.004599      0.003802
# 13   120Min    0.005923  0.033823     0.006201      0.005191
# 14   180Min    0.006189  0.033875     0.006477      0.005528
# 15   240Min    0.007748  0.034229     0.008127      0.006968
# 16       1D    0.012850  0.035784     0.013226      0.011372
# 17       2D    0.016055  0.037532     0.017410      0.014249
# 18       1W    0.030642  0.048652     0.035517      0.024734
# 19       2W    0.036771  0.053434     0.041828      0.033250
# 20       1M    0.065134  0.073175     0.065185      0.047410
# 21       2M    0.102586  0.083372     0.076455      0.051652
# 22       3M    0.098622  0.094752     0.088726      0.062954
# 23       6M    0.143453  0.093988     0.087910      0.043717
#
#     mean to prev mean  mean to end
# 0            0.000809     0.000219
# 1            0.001104     0.000338
# 2            0.001306     0.000500
# 3            0.001491     0.000527
# 4            0.001666     0.000575
# 5            0.001824     0.000612
# 6            0.001974     0.000664
# 7            0.002099     0.000686
# 8            0.002216     0.000734
# 9            0.002359     0.000747
# 10           0.002884     0.000890
# 11           0.004081     0.001233
# 12           0.005615     0.001671
# 13           0.007676     0.002312
# 14           0.008170     0.002280
# 15           0.010384     0.002859
# 16           0.017513     0.003508
# 17           0.021762     0.006591
# 18           0.038042     0.016606
# 19           0.048821     0.025891
# 20           0.062399     0.023210
# 21           0.074503     0.046257
# 22           0.044066     0.037066
# 23                NaN     0.042897

# %% [markdown]
# ## Predicting 60 min ahead using 10, 15, 20 and 30 minutes windows

# %%
def resample_single_stock(single_stock, interval):
    return pd.DataFrame({
        'MaxPrice': single_stock['MaxPrice'].resample(interval).max(),
        'MinPrice': single_stock['MinPrice'].resample(interval).min(),
        'LastEndPrice': single_stock['EndPrice'].resample(interval).last(),
        'FirstStartPrice': single_stock['StartPrice'].resample(interval).first(),         
        'MeanEndPrice': single_stock['EndPrice'].resample(interval).mean(),        
        'HasTrade': single_stock['HasTrade'].resample(interval).max(),
    })

def prepare_single_stock_multi_intervals(mnemonic, predicted_price, main_interval, intervals):
    single_stock = df[df.Mnemonic == mnemonic].copy()
        
    main = resample_single_stock(single_stock, main_interval)
    # we use the same anchor
    anchor = main['MeanEndPrice']
    future_mean_price = main[predicted_price].shift(-1)
    main['AdjustedPctChange[t + 1]'] = (future_mean_price - anchor)/anchor
    
    all_intervals = [main_interval] + intervals
    
    for interval in all_intervals:
        sub = resample_single_stock(single_stock, interval)
        resampled = sub.resample(main_interval).last() 

        main['Direction@' + interval] = \
            2.0*(resampled['LastEndPrice'] - resampled['FirstStartPrice'])/ \
            anchor

        main['H1@' + interval] = - closer_to_with_normalization(
                                                 resampled['LastEndPrice'], 
                                                 resampled['MaxPrice'], 
                                                 resampled['MinPrice'],
                                                 anchor)    
        
        main['EndToMean@' + interval] = (resampled['LastEndPrice'] - resampled['MeanEndPrice'])/anchor
        
    main = main[main['HasTrade'] == 1.0]
    main = main.drop(columns = [
        'MaxPrice',
        'MinPrice',
        'LastEndPrice',
        'FirstStartPrice',         
        'MeanEndPrice',     
        'HasTrade'       
    ])
    return main

# %%
main_interval = '60Min'
intervals = ['2Min', '5Min', '10Min', '15Min', '20Min', '30Min']

single_stock = prepare_single_stock_multi_intervals('SIE', 'MeanEndPrice', main_interval, intervals)

k = 'AdjustedPctChange[t + 1]'
single_stock.corr()[[k]].sort_values(k, ascending=False)
# Out:
#                           AdjustedPctChange[t + 1]
# AdjustedPctChange[t + 1]                  1.000000
# EndToMean@60Min                           0.694064
# Direction@30Min                           0.635698
# H1@60Min                                  0.611090
# H1@30Min                                  0.586646
# EndToMean@30Min                           0.577795
# Direction@20Min                           0.546220
# Direction@60Min                           0.512021
# Direction@15Min                           0.488824
# EndToMean@20Min                           0.479197
# H1@20Min                                  0.465178
# EndToMean@15Min                           0.405790
# H1@15Min                                  0.392962
# Direction@10Min                           0.387111
# EndToMean@10Min                           0.314600
# H1@10Min                                  0.299952
# Direction@5Min                            0.244654
# EndToMean@5Min                            0.222238
# H1@5Min                                   0.202317
# Direction@2Min                            0.185706
# H1@2Min                                   0.138499
# EndToMean@2Min                            0.113287

# %%
main_interval = '60Min'
intervals = ['2Min', '5Min', '10Min', '15Min', '20Min', '30Min']

single_stock = prepare_single_stock_multi_intervals('SIE', 'LastEndPrice', main_interval, intervals)

k = 'AdjustedPctChange[t + 1]'
single_stock.corr()[[k]].sort_values(k, ascending=False)
# Out:
#                           AdjustedPctChange[t + 1]
# AdjustedPctChange[t + 1]                  1.000000
# EndToMean@60Min                           0.506684
# Direction@30Min                           0.471918
# H1@60Min                                  0.449346
# H1@30Min                                  0.431266
# EndToMean@30Min                           0.429110
# Direction@20Min                           0.409199
# Direction@60Min                           0.384595
# Direction@15Min                           0.358005
# EndToMean@20Min                           0.351780
# H1@20Min                                  0.340792
# EndToMean@15Min                           0.294153
# H1@15Min                                  0.283002
# Direction@10Min                           0.282641
# EndToMean@10Min                           0.225990
# H1@10Min                                  0.212688
# Direction@5Min                            0.172358
# EndToMean@5Min                            0.153097
# H1@5Min                                   0.143850
# Direction@2Min                            0.131401
# H1@2Min                                   0.088101
# EndToMean@2Min                            0.064494
